# %% [markdown]
# <a href="https://colab.research.google.com/github/vamsivk18/COMP6721_Winter2023_GroupM/blob/Development/InceptionV3_2classes_0.0002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch.nn as nn
import torch
import torchvision.transforms as transforms
from torchsummary import summary
import torchvision
import time
 
import numpy as np
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import os
from google.colab import files
from google.colab import drive
import torchvision.models as models

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from zipfile import *
file_name = "/content/drive/MyDrive//dataset_2_classes.zip" 
with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
def get_mean_std(loader):
    mean = 0.
    std = 0.
    total_images_count = 0
    for images,_ in loader:
        images_count_in_batch = images.size(0)
#         print(images.shape)
        images =images.view(images_count_in_batch,images.size(1),-1)
        mean+=images.mean(2).sum(0)
        std+=images.std(2).sum(0)
        total_images_count+=images_count_in_batch
    mean /= total_images_count
    std /= total_images_count
    return mean,std

# %%
def transform(dataset):
    data_transform = transforms.Compose([transforms.Resize((224,224)),transforms.ToTensor()])
    data_set=torchvision.datasets.ImageFolder(root=dataset,transform=data_transform)
    data_loader=torch.utils.data.DataLoader(dataset=data_set,batch_size=32,shuffle=True)
    mean,std=get_mean_std(data_loader)
    data_transform = transforms.Compose([
        transforms.Resize((299,299)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(10),
        transforms.ToTensor(),
        transforms.Normalize(torch.Tensor(mean),torch.Tensor(std))
    ])
    data_set=torchvision.datasets.ImageFolder(root=dataset,transform=data_transform)
    data_loader=torch.utils.data.DataLoader(dataset=data_set,batch_size=32,shuffle=True,drop_last=False,num_workers=0)
    return data_loader,data_set

# %%
train_dataset='dataset_2_classes/train/'
train_loader,training_dataset=transform(train_dataset)

# %%
validate_dataset='dataset_2_classes/validate/'
validate_loader,validating_dataset=transform(validate_dataset)

# %%
test_dataset='dataset_2_classes/test/'
test_loader,testing_dataset=transform(test_dataset)

# %%
def set_device():
    device= torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    return device

# %%
device=set_device()

# %%
def get_model():
    model = models.inception_v3(pretrained=False)
    for param in model.parameters():
        param.requires_grad = False #Freezing all the layers and changing only the below layers
    model.avgpool = nn.AdaptiveAvgPool2d(output_size=(1,1))
    model.fc = nn.Sequential(nn.Flatten(),
                            nn.Linear(2048,128),
                            nn.ReLU(),
                            nn.Linear(128,2))
    model.aux_logits = False
    loss_fn = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=0.0002,momentum=0.9)
    return model.to(device), loss_fn, optimizer

# %%
def train_batch(images, labels, model, opt, loss_fn):
    output = model(images)
#     print(f"type of output - {type(output)}")
    batch_loss = loss_fn(output, labels)
    batch_loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    return batch_loss.item()

# %%
@torch.no_grad()
def accuracy(images, labels, model):
    model.eval()
    prediction = model(images)
    max_values, argmaxes = prediction.max(-1)
    is_correct = argmaxes == labels
    return is_correct.cpu().numpy().tolist()

# %%
@torch.no_grad()
def val_loss(x, y, model):
    model.eval()
    prediction = model(x)
    val_loss = loss_fn(prediction, y)
    return val_loss.item()

# %%
model, loss_fn, optimizer = get_model()
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /usr/local/lib/python3.9/dist-packages/torchvision/models/inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(

# %%
n_epochs = 100
train_losses, train_accuracies = [], []
val_losses, val_accuracies = [], []
for epoch in range(n_epochs):
    print("Epoch: %d "%(epoch+1))
    train_epoch_losses, train_epoch_accuracies = [], []
    for i,data in enumerate(iter(train_loader)):
        images,labels=data
        images=images.to(device)
        labels=labels.to(device)
        batch_loss = train_batch(images, labels, model, optimizer, loss_fn)
        is_correct = accuracy(images, labels, model)
        train_epoch_accuracies.extend(is_correct)
        train_epoch_losses.append(batch_loss)        
    train_epoch_loss = np.array(train_epoch_losses).mean()
    train_epoch_accuracy = np.mean(train_epoch_accuracies)*100      
    print('Epoch:',epoch+1,'Train Loss:',train_epoch_loss,'Train Accuracy:',train_epoch_accuracy)

    for i,data in enumerate(iter(validate_loader)):
        images,labels=data
        images=images.to(device)
        labels=labels.to(device)
        val_is_correct = accuracy(images, labels, model)
        validation_loss = val_loss(images, labels, model)    
        val_epoch_accuracy = np.mean(val_is_correct)*100

    print('Epoch:',epoch+1,'Validation Loss:',validation_loss,'Validation Accuracy:',val_epoch_accuracy)

    train_losses.append(train_epoch_loss)
    train_accuracies.append(train_epoch_accuracy)
    val_losses.append(validation_loss)
    val_accuracies.append(val_epoch_accuracy)
# Out:
# Epoch: 1
# Epoch: 1 Train Loss: 3.3536054625215197e+19 Train Accuracy: 77.0
# Epoch: 1 Validation Loss: 0.6813893914222717 Validation Accuracy: 83.33333333333334
# Epoch: 2
# Epoch: 2 Train Loss: 549.1170804061388 Train Accuracy: 80.0
# Epoch: 2 Validation Loss: 0.6811124086380005 Validation Accuracy: 72.22222222222221
# Epoch: 3
# Epoch: 3 Train Loss: 0.6738351050176119 Train Accuracy: 80.0
# Epoch: 3 Validation Loss: 0.6765741109848022 Validation Accuracy: 72.22222222222221
# Epoch: 4
# Epoch: 4 Train Loss: 0.6678423975643358 Train Accuracy: 80.0
# Epoch: 4 Validation Loss: 0.6667550206184387 Validation Accuracy: 77.77777777777779
# Epoch: 5
# Epoch: 5 Train Loss: 0.6618920596022355 Train Accuracy: 80.0
# Epoch: 5 Validation Loss: 0.6482136845588684 Validation Accuracy: 88.88888888888889
# Epoch: 6
# Epoch: 6 Train Loss: 0.6564180286307084 Train Accuracy: 80.0
# Epoch: 6 Validation Loss: 0.6486884951591492 Validation Accuracy: 83.33333333333334
# Epoch: 7
# Epoch: 7 Train Loss: 0.6509481793955753 Train Accuracy: 80.0
# Epoch: 7 Validation Loss: 0.6338053941726685 Validation Accuracy: 88.88888888888889
# Epoch: 8
# Epoch: 8 Train Loss: 0.6458181174177873 Train Accuracy: 80.0
# Epoch: 8 Validation Loss: 0.6471197009086609 Validation Accuracy: 77.77777777777779
# Epoch: 9
# Epoch: 9 Train Loss: 0.6410315789674458 Train Accuracy: 80.0
# Epoch: 9 Validation Loss: 0.6426093578338623 Validation Accuracy: 77.77777777777779
# Epoch: 10
# Epoch: 10 Train Loss: 0.6362448742515162 Train Accuracy: 80.0
# Epoch: 10 Validation Loss: 0.6626390814781189 Validation Accuracy: 66.66666666666666
# Epoch: 11
# Epoch: 11 Train Loss: 0.6312914082878515 Train Accuracy: 80.0
# Epoch: 11 Validation Loss: 0.6869879364967346 Validation Accuracy: 55.55555555555556
# Epoch: 12
# Epoch: 12 Train Loss: 0.6265987910722431 Train Accuracy: 80.0
# Epoch: 12 Validation Loss: 0.6018854975700378 Validation Accuracy: 88.88888888888889
# Epoch: 13
# Epoch: 13 Train Loss: 0.6224682205601743 Train Accuracy: 80.0
# Epoch: 13 Validation Loss: 0.61128830909729 Validation Accuracy: 83.33333333333334
# Epoch: 14
# Epoch: 14 Train Loss: 0.6183264130040219 Train Accuracy: 80.0
# Epoch: 14 Validation Loss: 0.6228150725364685 Validation Accuracy: 77.77777777777779
# Epoch: 15
# Epoch: 15 Train Loss: 0.6141313126212672 Train Accuracy: 80.0
# Epoch: 15 Validation Loss: 0.5850803256034851 Validation Accuracy: 88.88888888888889
# Epoch: 16
# Epoch: 16 Train Loss: 0.6105321112431978 Train Accuracy: 80.0
# Epoch: 16 Validation Loss: 0.5977440476417542 Validation Accuracy: 83.33333333333334
# Epoch: 17
# Epoch: 17 Train Loss: 0.6077140946137277 Train Accuracy: 80.0
# Epoch: 17 Validation Loss: 0.5935328006744385 Validation Accuracy: 83.33333333333334
# Epoch: 18
# Epoch: 18 Train Loss: 0.6035738712862918 Train Accuracy: 80.0
# Epoch: 18 Validation Loss: 0.6294488310813904 Validation Accuracy: 72.22222222222221
# Epoch: 19
# Epoch: 19 Train Loss: 0.6008311102264806 Train Accuracy: 80.0
# Epoch: 19 Validation Loss: 0.5857102870941162 Validation Accuracy: 83.33333333333334
# Epoch: 20
# Epoch: 20 Train Loss: 0.5969553276112205 Train Accuracy: 80.0
# Epoch: 20 Validation Loss: 0.6253286004066467 Validation Accuracy: 72.22222222222221
# Epoch: 21
# Epoch: 21 Train Loss: 0.5933340003615931 Train Accuracy: 80.0
# Epoch: 21 Validation Loss: 0.6008880138397217 Validation Accuracy: 77.77777777777779
# Epoch: 22
# Epoch: 22 Train Loss: 0.5907084283075834 Train Accuracy: 80.0
# Epoch: 22 Validation Loss: 0.6216223835945129 Validation Accuracy: 72.22222222222221
# Epoch: 23
# Epoch: 23 Train Loss: 0.5873391283185858 Train Accuracy: 80.0
# Epoch: 23 Validation Loss: 0.6682795286178589 Validation Accuracy: 61.111111111111114
# Epoch: 24
# Epoch: 24 Train Loss: 0.5849170496589259 Train Accuracy: 80.0
# Epoch: 24 Validation Loss: 0.568182110786438 Validation Accuracy: 83.33333333333334
# Epoch: 25
# Epoch: 25 Train Loss: 0.5824449940731651 Train Accuracy: 80.0
# Epoch: 25 Validation Loss: 0.5908522009849548 Validation Accuracy: 77.77777777777779
# Epoch: 26
# Epoch: 26 Train Loss: 0.5793687230662296 Train Accuracy: 80.0
# Epoch: 26 Validation Loss: 0.6417194604873657 Validation Accuracy: 66.66666666666666
# Epoch: 27
# Epoch: 27 Train Loss: 0.5758967399597168 Train Accuracy: 80.0
# Epoch: 27 Validation Loss: 0.695795476436615 Validation Accuracy: 55.55555555555556
# Epoch: 28
# Epoch: 28 Train Loss: 0.5739887105791193 Train Accuracy: 80.0
# Epoch: 28 Validation Loss: 0.6685917973518372 Validation Accuracy: 61.111111111111114
# Epoch: 29
# Epoch: 29 Train Loss: 0.5716129666880557 Train Accuracy: 80.0
# Epoch: 29 Validation Loss: 0.6399329304695129 Validation Accuracy: 66.66666666666666
# Epoch: 30
# Epoch: 30 Train Loss: 0.5693372754674209 Train Accuracy: 80.0
# Epoch: 30 Validation Loss: 0.5506033897399902 Validation Accuracy: 83.33333333333334
# Epoch: 31
# Epoch: 31 Train Loss: 0.567074245528171 Train Accuracy: 80.0
# Epoch: 31 Validation Loss: 0.5783159732818604 Validation Accuracy: 77.77777777777779
# Epoch: 32
# Epoch: 32 Train Loss: 0.564921310073451 Train Accuracy: 80.0
# Epoch: 32 Validation Loss: 0.5765020251274109 Validation Accuracy: 77.77777777777779
# Epoch: 33
# Epoch: 33 Train Loss: 0.5627375150981703 Train Accuracy: 80.0
# Epoch: 33 Validation Loss: 0.5430418252944946 Validation Accuracy: 83.33333333333334
# Epoch: 34
# Epoch: 34 Train Loss: 0.5615158833955464 Train Accuracy: 80.0
# Epoch: 34 Validation Loss: 0.5730687379837036 Validation Accuracy: 77.77777777777779
# Epoch: 35
# Epoch: 35 Train Loss: 0.5589638195539776 Train Accuracy: 80.0
# Epoch: 35 Validation Loss: 0.6045116782188416 Validation Accuracy: 72.22222222222221
# Epoch: 36
# Epoch: 36 Train Loss: 0.5557225848499098 Train Accuracy: 80.0
# Epoch: 36 Validation Loss: 0.6710577607154846 Validation Accuracy: 61.111111111111114
# Epoch: 37
# Epoch: 37 Train Loss: 0.5548995121529228 Train Accuracy: 80.0
# Epoch: 37 Validation Loss: 0.5340790152549744 Validation Accuracy: 83.33333333333334
# Epoch: 38
# Epoch: 38 Train Loss: 0.5552968335779089 Train Accuracy: 80.0
# Epoch: 38 Validation Loss: 0.6369575262069702 Validation Accuracy: 66.66666666666666
# Epoch: 39
# Epoch: 39 Train Loss: 0.5533038879695692 Train Accuracy: 80.0
# Epoch: 39 Validation Loss: 0.45860978960990906 Validation Accuracy: 94.44444444444444
# Epoch: 40
# Epoch: 40 Train Loss: 0.5506126864960319 Train Accuracy: 80.0
# Epoch: 40 Validation Loss: 0.7091574668884277 Validation Accuracy: 55.55555555555556
# Epoch: 41
# Epoch: 41 Train Loss: 0.548340977806794 Train Accuracy: 80.0
# Epoch: 41 Validation Loss: 0.4893757104873657 Validation Accuracy: 88.88888888888889
# Epoch: 42
# Epoch: 42 Train Loss: 0.5487526153263292 Train Accuracy: 80.0
# Epoch: 42 Validation Loss: 0.561654806137085 Validation Accuracy: 77.77777777777779
# Epoch: 43
# Epoch: 43 Train Loss: 0.5457416129739661 Train Accuracy: 80.0
# Epoch: 43 Validation Loss: 0.48446929454803467 Validation Accuracy: 88.88888888888889
# Epoch: 44
# Epoch: 44 Train Loss: 0.5439571989210028 Train Accuracy: 80.0
# Epoch: 44 Validation Loss: 0.5979407429695129 Validation Accuracy: 72.22222222222221
# Epoch: 45
# Epoch: 45 Train Loss: 0.5429860541695043 Train Accuracy: 80.0
# Epoch: 45 Validation Loss: 0.6756707429885864 Validation Accuracy: 61.111111111111114
# Epoch: 46
# Epoch: 46 Train Loss: 0.5416455504141355 Train Accuracy: 80.0
# Epoch: 46 Validation Loss: 0.5571961402893066 Validation Accuracy: 77.77777777777779
# Epoch: 47
# Epoch: 47 Train Loss: 0.5407697134896329 Train Accuracy: 80.0
# Epoch: 47 Validation Loss: 0.6366194486618042 Validation Accuracy: 66.66666666666666
# Epoch: 48
# Epoch: 48 Train Loss: 0.5387634164408633 Train Accuracy: 80.0
# Epoch: 48 Validation Loss: 0.5551568865776062 Validation Accuracy: 77.77777777777779
# Epoch: 49
# Epoch: 49 Train Loss: 0.539586465609701 Train Accuracy: 80.0
# Epoch: 49 Validation Loss: 0.5954912304878235 Validation Accuracy: 72.22222222222221
# Epoch: 50
# Epoch: 50 Train Loss: 0.5359701827952736 Train Accuracy: 80.0
# Epoch: 50 Validation Loss: 0.5951008796691895 Validation Accuracy: 72.22222222222221
# Epoch: 51
# Epoch: 51 Train Loss: 0.5365444327655592 Train Accuracy: 80.0
# Epoch: 51 Validation Loss: 0.679364025592804 Validation Accuracy: 61.111111111111114
# Epoch: 52
# Epoch: 52 Train Loss: 0.5346017197558754 Train Accuracy: 80.0
# Epoch: 52 Validation Loss: 0.7227980494499207 Validation Accuracy: 55.55555555555556
# Epoch: 53
# Epoch: 53 Train Loss: 0.5344278326160029 Train Accuracy: 80.0
# Epoch: 53 Validation Loss: 0.5074171423912048 Validation Accuracy: 83.33333333333334
# Epoch: 54
# Epoch: 54 Train Loss: 0.53300457565408 Train Accuracy: 80.0
# Epoch: 54 Validation Loss: 0.7688856720924377 Validation Accuracy: 50.0
# Epoch: 55
# Epoch: 55 Train Loss: 0.5315925353451779 Train Accuracy: 80.0
# Epoch: 55 Validation Loss: 0.5934281349182129 Validation Accuracy: 72.22222222222221
# Epoch: 56
# Epoch: 56 Train Loss: 0.5310773206384558 Train Accuracy: 80.0
# Epoch: 56 Validation Loss: 0.6826050281524658 Validation Accuracy: 61.111111111111114
# Epoch: 57
# Epoch: 57 Train Loss: 0.5306495647681387 Train Accuracy: 80.0
# Epoch: 57 Validation Loss: 0.6381044387817383 Validation Accuracy: 66.66666666666666
# Epoch: 58
# Epoch: 58 Train Loss: 0.5293072603250805 Train Accuracy: 80.0
# Epoch: 58 Validation Loss: 0.7752910852432251 Validation Accuracy: 50.0
# Epoch: 59
# Epoch: 59 Train Loss: 0.5279845297336578 Train Accuracy: 80.0
# Epoch: 59 Validation Loss: 0.5463831424713135 Validation Accuracy: 77.77777777777779
# Epoch: 60
# Epoch: 60 Train Loss: 0.5265791024032392 Train Accuracy: 80.0
# Epoch: 60 Validation Loss: 0.592265784740448 Validation Accuracy: 72.22222222222221
# Epoch: 61
# Epoch: 61 Train Loss: 0.5268450191146449 Train Accuracy: 80.0
# Epoch: 61 Validation Loss: 0.5920782685279846 Validation Accuracy: 72.22222222222221
# Epoch: 62
# Epoch: 62 Train Loss: 0.5265590579886186 Train Accuracy: 80.0
# Epoch: 62 Validation Loss: 0.5919024348258972 Validation Accuracy: 72.22222222222221
# Epoch: 63
# Epoch: 63 Train Loss: 0.5252800097590998 Train Accuracy: 80.0
# Epoch: 63 Validation Loss: 0.6395549178123474 Validation Accuracy: 66.66666666666666
# Epoch: 64
# Epoch: 64 Train Loss: 0.5229509504217851 Train Accuracy: 80.0
# Epoch: 64 Validation Loss: 0.832543671131134 Validation Accuracy: 44.44444444444444
# Epoch: 65
# Epoch: 65 Train Loss: 0.5248796045780182 Train Accuracy: 80.0
# Epoch: 65 Validation Loss: 0.7373442053794861 Validation Accuracy: 55.55555555555556
# Epoch: 66
# Epoch: 66 Train Loss: 0.5211856004438902 Train Accuracy: 80.0
# Epoch: 66 Validation Loss: 0.5424036979675293 Validation Accuracy: 77.77777777777779
# Epoch: 67
# Epoch: 67 Train Loss: 0.5211057098288285 Train Accuracy: 80.0
# Epoch: 67 Validation Loss: 0.5418983101844788 Validation Accuracy: 77.77777777777779
# Epoch: 68
# Epoch: 68 Train Loss: 0.5209558543406034 Train Accuracy: 80.0
# Epoch: 68 Validation Loss: 0.6409996747970581 Validation Accuracy: 66.66666666666666
# Epoch: 69
# Epoch: 69 Train Loss: 0.5207959084134353 Train Accuracy: 80.0
# Epoch: 69 Validation Loss: 0.6413084864616394 Validation Accuracy: 66.66666666666666
# Epoch: 70
# Epoch: 70 Train Loss: 0.5191800327677476 Train Accuracy: 80.0
# Epoch: 70 Validation Loss: 0.591050922870636 Validation Accuracy: 72.22222222222221
# Epoch: 71
# Epoch: 71 Train Loss: 0.5221140792495326 Train Accuracy: 80.0
# Epoch: 71 Validation Loss: 0.6419298648834229 Validation Accuracy: 66.66666666666666
# Epoch: 72
# Epoch: 72 Train Loss: 0.5225838030639448 Train Accuracy: 80.0
# Epoch: 72 Validation Loss: 0.48835816979408264 Validation Accuracy: 83.33333333333334
# Epoch: 73
# Epoch: 73 Train Loss: 0.5190089846912184 Train Accuracy: 80.0
# Epoch: 73 Validation Loss: 0.5909111499786377 Validation Accuracy: 72.22222222222221
# Epoch: 74
# Epoch: 74 Train Loss: 0.5205717086791992 Train Accuracy: 80.0
# Epoch: 74 Validation Loss: 0.6948863863945007 Validation Accuracy: 61.111111111111114
# Epoch: 75
# Epoch: 75 Train Loss: 0.5195342741514507 Train Accuracy: 80.0
# Epoch: 75 Validation Loss: 0.4862135648727417 Validation Accuracy: 83.33333333333334
# Epoch: 76
# Epoch: 76 Train Loss: 0.5164917707443237 Train Accuracy: 80.0
# Epoch: 76 Validation Loss: 0.6961964964866638 Validation Accuracy: 61.111111111111114
# Epoch: 77
# Epoch: 77 Train Loss: 0.5154534123445812 Train Accuracy: 80.0
# Epoch: 77 Validation Loss: 0.6968463063240051 Validation Accuracy: 61.111111111111114
# Epoch: 78
# Epoch: 78 Train Loss: 0.5149532948669634 Train Accuracy: 80.0
# Epoch: 78 Validation Loss: 0.6441469192504883 Validation Accuracy: 66.66666666666666
# Epoch: 79
# Epoch: 79 Train Loss: 0.5144975342248616 Train Accuracy: 80.0
# Epoch: 79 Validation Loss: 0.7517227530479431 Validation Accuracy: 55.55555555555556
# Epoch: 80
# Epoch: 80 Train Loss: 0.5151122322208003 Train Accuracy: 80.0
# Epoch: 80 Validation Loss: 0.4829657971858978 Validation Accuracy: 83.33333333333334
# Epoch: 81
# Epoch: 81 Train Loss: 0.5135972342993084 Train Accuracy: 80.0
# Epoch: 81 Validation Loss: 0.6993719935417175 Validation Accuracy: 61.111111111111114
# Epoch: 82
# Epoch: 82 Train Loss: 0.5142855220719388 Train Accuracy: 80.0
# Epoch: 82 Validation Loss: 0.5909170508384705 Validation Accuracy: 72.22222222222221
# Epoch: 83
# Epoch: 83 Train Loss: 0.5143800017080808 Train Accuracy: 80.0
# Epoch: 83 Validation Loss: 0.5909490585327148 Validation Accuracy: 72.22222222222221
# Epoch: 84
# Epoch: 84 Train Loss: 0.5145436603772012 Train Accuracy: 80.0
# Epoch: 84 Validation Loss: 0.590986967086792 Validation Accuracy: 72.22222222222221
# Epoch: 85
# Epoch: 85 Train Loss: 0.514736500225569 Train Accuracy: 80.0
# Epoch: 85 Validation Loss: 0.4244793653488159 Validation Accuracy: 88.88888888888889
# Epoch: 86
# Epoch: 86 Train Loss: 0.5154664610561571 Train Accuracy: 80.0
# Epoch: 86 Validation Loss: 0.5352758765220642 Validation Accuracy: 77.77777777777779
# Epoch: 87
# Epoch: 87 Train Loss: 0.5134780359895605 Train Accuracy: 80.0
# Epoch: 87 Validation Loss: 0.422852486371994 Validation Accuracy: 88.88888888888889
# Epoch: 88
# Epoch: 88 Train Loss: 0.5125693490630702 Train Accuracy: 80.0
# Epoch: 88 Validation Loss: 0.7039007544517517 Validation Accuracy: 61.111111111111114
# Epoch: 89
# Epoch: 89 Train Loss: 0.5105722185812498 Train Accuracy: 80.0
# Epoch: 89 Validation Loss: 0.7611466646194458 Validation Accuracy: 55.55555555555556
# Epoch: 90
# Epoch: 90 Train Loss: 0.5124930378637815 Train Accuracy: 80.0
# Epoch: 90 Validation Loss: 0.5913175940513611 Validation Accuracy: 72.22222222222221
# Epoch: 91
# Epoch: 91 Train Loss: 0.5115899051490583 Train Accuracy: 80.0
# Epoch: 91 Validation Loss: 0.7629043459892273 Validation Accuracy: 55.55555555555556
# Epoch: 92
# Epoch: 92 Train Loss: 0.5118891894817352 Train Accuracy: 80.0
# Epoch: 92 Validation Loss: 0.6489298343658447 Validation Accuracy: 66.66666666666666
# Epoch: 93
# Epoch: 93 Train Loss: 0.5115574959077334 Train Accuracy: 80.0
# Epoch: 93 Validation Loss: 0.5915267467498779 Validation Accuracy: 72.22222222222221
# Epoch: 94
# Epoch: 94 Train Loss: 0.5112861630163694 Train Accuracy: 80.0
# Epoch: 94 Validation Loss: 0.5336506962776184 Validation Accuracy: 77.77777777777779
# Epoch: 95
# Epoch: 95 Train Loss: 0.509960778449711 Train Accuracy: 80.0
# Epoch: 95 Validation Loss: 0.4170142710208893 Validation Accuracy: 88.88888888888889
# Epoch: 96
# Epoch: 96 Train Loss: 0.5107511078056536 Train Accuracy: 80.0
# Epoch: 96 Validation Loss: 0.5917730927467346 Validation Accuracy: 72.22222222222221
# Epoch: 97
# Epoch: 97 Train Loss: 0.5104905664920807 Train Accuracy: 80.0
# Epoch: 97 Validation Loss: 0.4744303524494171 Validation Accuracy: 83.33333333333334
# Epoch: 98
# Epoch: 98 Train Loss: 0.5102481151881971 Train Accuracy: 80.0
# Epoch: 98 Validation Loss: 0.4740131199359894 Validation Accuracy: 83.33333333333334
# Epoch: 99
# Epoch: 99 Train Loss: 0.5094113240116521 Train Accuracy: 80.0
# Epoch: 99 Validation Loss: 0.6512401103973389 Validation Accuracy: 66.66666666666666
# Epoch: 100
# Epoch: 100 Train Loss: 0.507987285915174 Train Accuracy: 80.0
# Epoch: 100 Validation Loss: 0.5921217203140259 Validation Accuracy: 72.22222222222221

# %%
def evaluate_model(model,test_loader):
    model.eval()
    predicted_correct =0
    total = 0
    with torch.no_grad():
        for data in test_loader:
            images,labels = data
            images = images.to(device)
            labels = labels.to(device)
            predicted_correct= accuracy(images, labels, model)
    epoch_accuracy = np.mean(val_is_correct)*100
    print("Testing Data: Epoch Accuracy: %.3f"%(epoch_accuracy))
    return epoch_accuracy

# %%
evaluate_model(model,test_loader)
# Out:
# Testing Data: Epoch Accuracy: 72.222
# 72.22222222222221

# %%
dict = {'Training': train_accuracies, 'Validation': val_accuracies} 
dictLoss = {'Training': train_losses,'Validation': val_losses}
df = pd.DataFrame(dict)
df2 = pd.DataFrame(dictLoss)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(range(n_epochs),train_accuracies)
plt.xlabel("Epochs")
plt.ylabel("Training Accuracies")
plt.title("Training Accuracy Vs Epochs")
plt.show()

# %%
plt.plot(range(n_epochs),train_accuracies, label="Training")
plt.plot(range(n_epochs),val_accuracies, label="Validation")
plt.xlabel("Epochs")
plt.ylabel("Accuracies")
plt.title("Training vs Validation Accuracies")
plt.legend()
plt.show()

# %%
plt.plot(range(n_epochs),train_losses, label="Training")
plt.plot(range(n_epochs),val_losses, label="Validation")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score,ConfusionMatrixDisplay

# %%
y_pred = []
y_true = []

for data in test_loader:
        inputs, labels = data[0].to(device), data[1].to(device)
        output = model(inputs) 
        output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
        y_pred.extend(output) 
        labels = labels.data.cpu().numpy()
        y_true.extend(labels)

# %%
classes = (0,1)
confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix(y_true, y_pred),display_labels=classes)
fig,ax = plt.subplots()
fig.set_size_inches(13,13)
plt.title("Confusion Matrix GoogleNet (2-Classes)")
disp.plot(ax=ax)
plt.show()

# %%
print("Precision Macro:{:.2f}".format(precision_score(y_true, y_pred, average='macro')))
print("Precision Micro:{:.2f}".format(precision_score(y_true,y_pred,average='micro')))
print("Recall Macro:{:.2f}".format(recall_score(y_true,y_pred,average='macro')))
print("Recall Micro:{:.2f}".format(recall_score(y_true,y_pred,average='micro')))
print("F1-Score Macro:{:.2f}".format(f1_score(y_true,y_pred,average='macro')))
print("F1-Score Micro:{:.2f}".format(f1_score(y_true,y_pred,average='micro')))
# Out:
# Precision Macro:0.41
# Precision Micro:0.81
# Recall Macro:0.50
# Recall Micro:0.81
# F1-Score Macro:0.45
# F1-Score Micro:0.81
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
