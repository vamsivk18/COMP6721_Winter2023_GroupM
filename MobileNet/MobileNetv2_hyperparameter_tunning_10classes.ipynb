# %%
import torch.nn as nn
import torch
import torchvision.transforms as transforms
import torchvision
import time
import matplotlib.pyplot as plt
import numpy as np
import torchvision.models as models
from sklearn.metrics import confusion_matrix
import pandas as pd
import os
import pathlib

# %%
def get_mean_std(loader):
    mean = 0.
    std = 0.
    total_images_count = 0
    for images,_ in loader:
        images_count_in_batch = images.size(0)
#         print(images.shape)
        images =images.view(images_count_in_batch,images.size(1),-1)
        mean+=images.mean(2).sum(0)
        std+=images.std(2).sum(0)
        total_images_count+=images_count_in_batch
    mean /= total_images_count
    std /= total_images_count
    return mean,std

# %%
def train_transform(dataset):
    train_transforms = transforms.Compose([transforms.Resize((224,224)),transforms.ToTensor()])
    train_dataset=torchvision.datasets.ImageFolder(root=dataset,transform=train_transforms)
    train_loader=torch.utils.data.DataLoader(dataset=train_dataset,batch_size=32,shuffle=True)
    mean,std=get_mean_std(train_loader)
    train_transforms = transforms.Compose([
        transforms.Resize((224,224)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(10),
        transforms.ToTensor(),
        transforms.Normalize(torch.Tensor(mean),torch.Tensor(std))
    ])
    data_set=torchvision.datasets.ImageFolder(root=dataset,transform=train_transforms)
    return data_set

# %%
path = "../Datasets/dataset_20_classes/"
dataset=train_transform(path)

# %%
root=pathlib.Path(path)
classes=sorted([j.name.split('/')[-1] for j in root.iterdir()])
classes=classes[1:]
print(classes)
# Out:
# ['Apple_healthy', 'Apple_unhealthy', 'Cherry_healthy', 'Cherry_unhealthy', 'Grape_healthy', 'Grape_unhealthy', 'Mango_healthy', 'Mango_unhealthy', 'Peach_healthy', 'Peach_unhealthy', 'Pepperbell_healthy', 'Pepperbell_unhealthy', 'Pomegranate_healthy', 'Pomegranate_unhealthy', 'Potato_healthy', 'Potato_unhealthy', 'Strawberry_healthy', 'Strawberry_unhealthy', 'Tomato_healthy', 'Tomato_unhealthy']

# %%
train_size = int(0.7 * len(dataset))
val_size = int(0.1 * len(dataset))
test_size = len(dataset)-train_size-val_size
train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, val_size,test_size])
print(str(train_size)+" "+str(val_size)+" "+str(test_size))
# Out:
# 13803 1971 3945

# %%
def set_device():
    device = "mps" if torch.backends.mps.is_available() else "cpu"
    return device

# %%
device=set_device()

# %%
lr = [1E-0, 1E-1, 1E-2, 1E-3, 1E-4]
Batchs=[64]
from statistics import mean
best_accuracy=0.0
best_param=""
criterion = nn.CrossEntropyLoss()
lr_accuract_training=[]
lr_accuracy_val=[]
lr_loss_train=[]
lr_loss_val=[]

# %%
for n in lr:
    model = models.mobilenet_v2(pretrained=False, num_classes = 20)
    model.to(device)
    print("Learning Rate: %.4f "%(n))
    optimizer = torch.optim.SGD(model.parameters(), lr=n,momentum=0.9)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=20, eta_min=0.0001)
    for Batch_size in Batchs:
        print("Batch Size: %d "%(Batch_size))
        training_loader=torch.utils.data.DataLoader(dataset=train_dataset,batch_size=Batch_size,shuffle=True,drop_last=False,num_workers=0)
        val_loader=torch.utils.data.DataLoader(dataset=val_dataset,batch_size=Batch_size,shuffle=False,drop_last=False,num_workers=0)
        n_epochs=50
        print("Epoch size: %d "%(n_epochs))
        epoch_count = 0
        Accuracies = [] 
        valAccuracies = []
        valLoss = []
        trainLoss = []
        t1 = time.time()
        validation_accuracy = 0
        for epoch in range(n_epochs):
            print("Epoch: %d "%(epoch+1))
            model.train()
            running_loss=0.0
            running_correct=0.0
            val_loss=0.0
            total=0
            for i,data in enumerate(training_loader):
                images,labels=data
                images=images.to(device)
                labels=labels.to(device)
                total+=labels.size(0)
                optimizer.zero_grad()
                outputs=model(images)
                _,predicted=torch.max(outputs.data,1)
                loss=criterion(outputs,labels)
                loss.backward()
                optimizer.step()
                running_loss+=loss.item()
                running_correct+=(labels==predicted).sum().item()
                traning_accuracy=(running_correct/total)*100
                    
            validation_accuracy=0
            model.eval()
            with torch.no_grad():
                val_correct=0
                val_total=0
                val_loss=0
                for data in val_loader:
                    images,val_labels=data[0].to(device), data[1].to(device)
                    images = images.to(device)
                    val_labels = val_labels.to(device)
                    outputs=model(images)
                    loss_val=criterion(outputs,val_labels)
                    val_loss+= loss_val.item()
                    _,predicted=torch.max(outputs.data,1)
                    val_correct+=(predicted == val_labels).sum().item()
                    val_total+=val_labels.size(0)
                validation_accuracy = (val_correct / val_total) *100
                    
            scheduler.step()
            epoch_loss=running_loss/len(training_loader)
            val_loss=val_loss/len(val_loader)
            epoch_accuracy=100.00* running_correct/total
            Accuracies.append(epoch_accuracy)
            valAccuracies.append(validation_accuracy)
            trainLoss.append(epoch_loss)
            valLoss.append(val_loss)
                
                
            print("Training Data: Epoch Loss: %.3f, Epoch Accuracy: %.3f, Validation Loss: %.3f,Validation Accuracy: %.3f"%(epoch_loss,epoch_accuracy,val_loss,validation_accuracy))
           
        
        print("######## epoch Finished in {} seconds ###########".format(time.time()\
                                                                    -t1))
        epoch_count+=n_epochs
        torch.save(model.state_dict(), "20-Class-MobileNetv2-"+str(epoch)+"_"+str(Batch_size)+"_"+str(n)+"-epoch.pt")
            
        plt.plot(range(n_epochs),Accuracies, label="Training")
        plt.plot(range(n_epochs),valAccuracies, label="Validation")
        plt.xlabel("Folds")
        plt.ylabel("Accuracies")
        plt.title("Training vs Validation vs Test Accuracies for epoches: %d, Batch Size: %d, Learning Rate: %.4f" % (n_epochs, Batch_size, n))
        plt.legend()
        plt.show()
            
        plt.plot(range(n_epochs),trainLoss, label="Training")
        plt.plot(range(n_epochs),valLoss, label="Validation")
        plt.xlabel("Epochs")
        plt.ylabel("Loss")
        plt.title("Training vs Validation vs Test Loss for epoches: %d, Batch Size: %d, Learning Rate: %.4f" % (n_epochs, Batch_size, n))
        plt.legend()
        plt.show()
        
        lr_accuract_training.append(mean(Accuracies))
        lr_accuracy_val.append(mean(valAccuracies))
        lr_loss_train.append(mean(trainLoss))
        lr_loss_val.append(mean(valLoss))
            
        val=mean(valAccuracies)
        #Save the best model
        if val>best_accuracy:
            torch.save(model.state_dict(),'best_checkpoint.model')
            best_accuracy=val
            best_param="Learning Rate: "+str(n)+" Batch Size: "+str(Batch_size)+" "
# Out:
# /Users/bhanuprakash/miniforge3/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/bhanuprakash/miniforge3/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Learning Rate: 1.0000
# Batch Size: 64
# Epoch size: 50
# Epoch: 1
# Training Data: Epoch Loss: 3.280, Epoch Accuracy: 31.855, Validation Loss: 2.429,Validation Accuracy: 33.638
# Epoch: 2
# Training Data: Epoch Loss: 2.412, Epoch Accuracy: 32.935, Validation Loss: 2.313,Validation Accuracy: 34.703
# Epoch: 3
# Training Data: Epoch Loss: 2.273, Epoch Accuracy: 33.877, Validation Loss: 2.298,Validation Accuracy: 36.276
# Epoch: 4
# Training Data: Epoch Loss: 2.129, Epoch Accuracy: 34.797, Validation Loss: 2.748,Validation Accuracy: 36.580
# Epoch: 5
# Training Data: Epoch Loss: 2.096, Epoch Accuracy: 36.181, Validation Loss: 2.101,Validation Accuracy: 38.407
# Epoch: 6
# Training Data: Epoch Loss: 1.954, Epoch Accuracy: 38.644, Validation Loss: 1.812,Validation Accuracy: 40.741
# Epoch: 7
# Training Data: Epoch Loss: 1.797, Epoch Accuracy: 42.426, Validation Loss: 1.770,Validation Accuracy: 40.589
# Epoch: 8
# Training Data: Epoch Loss: 1.771, Epoch Accuracy: 43.121, Validation Loss: 1.941,Validation Accuracy: 39.066
# Epoch: 9
# Training Data: Epoch Loss: 1.847, Epoch Accuracy: 40.882, Validation Loss: 1.900,Validation Accuracy: 42.618
# Epoch: 10
# Training Data: Epoch Loss: 1.691, Epoch Accuracy: 45.121, Validation Loss: 1.571,Validation Accuracy: 48.909
# Epoch: 11
# Training Data: Epoch Loss: 1.564, Epoch Accuracy: 48.526, Validation Loss: 1.457,Validation Accuracy: 51.750
# Epoch: 12
# Training Data: Epoch Loss: 1.442, Epoch Accuracy: 52.684, Validation Loss: 1.441,Validation Accuracy: 53.323
# Epoch: 13
# Training Data: Epoch Loss: 1.442, Epoch Accuracy: 52.677, Validation Loss: 1.236,Validation Accuracy: 58.194
# Epoch: 14
# Training Data: Epoch Loss: 1.352, Epoch Accuracy: 55.408, Validation Loss: 1.857,Validation Accuracy: 47.590
# Epoch: 15
# Training Data: Epoch Loss: 1.271, Epoch Accuracy: 58.096, Validation Loss: 1.121,Validation Accuracy: 63.927
# Epoch: 16
# Training Data: Epoch Loss: 1.189, Epoch Accuracy: 60.516, Validation Loss: 1.053,Validation Accuracy: 64.231
# Epoch: 17
# Training Data: Epoch Loss: 1.136, Epoch Accuracy: 62.581, Validation Loss: 1.022,Validation Accuracy: 65.601
# Epoch: 18
# Training Data: Epoch Loss: 1.083, Epoch Accuracy: 64.682, Validation Loss: 0.931,Validation Accuracy: 67.884
# Epoch: 19
# Training Data: Epoch Loss: 1.048, Epoch Accuracy: 65.667, Validation Loss: 0.913,Validation Accuracy: 69.863
# Epoch: 20
# Training Data: Epoch Loss: 1.034, Epoch Accuracy: 66.217, Validation Loss: 0.912,Validation Accuracy: 70.573
# Epoch: 21
# Training Data: Epoch Loss: 1.030, Epoch Accuracy: 66.102, Validation Loss: 0.913,Validation Accuracy: 69.153
# Epoch: 22
# Training Data: Epoch Loss: 1.030, Epoch Accuracy: 66.145, Validation Loss: 0.906,Validation Accuracy: 70.167
# Epoch: 23
# Training Data: Epoch Loss: 1.031, Epoch Accuracy: 65.747, Validation Loss: 0.896,Validation Accuracy: 70.573
# Epoch: 24
# Training Data: Epoch Loss: 1.034, Epoch Accuracy: 65.834, Validation Loss: 0.930,Validation Accuracy: 69.812
# Epoch: 25
# Training Data: Epoch Loss: 1.053, Epoch Accuracy: 65.406, Validation Loss: 0.893,Validation Accuracy: 70.218
# Epoch: 26
# Training Data: Epoch Loss: 1.076, Epoch Accuracy: 64.479, Validation Loss: 0.945,Validation Accuracy: 68.950
# Epoch: 27
# Training Data: Epoch Loss: 1.090, Epoch Accuracy: 63.733, Validation Loss: 0.984,Validation Accuracy: 68.189
# Epoch: 28
# Training Data: Epoch Loss: 1.118, Epoch Accuracy: 63.167, Validation Loss: 1.023,Validation Accuracy: 65.652
# Epoch: 29
# Training Data: Epoch Loss: 1.127, Epoch Accuracy: 62.233, Validation Loss: 1.061,Validation Accuracy: 64.637
# Epoch: 30
# Training Data: Epoch Loss: 1.100, Epoch Accuracy: 63.059, Validation Loss: 1.194,Validation Accuracy: 58.447
# Epoch: 31
# Training Data: Epoch Loss: 1.068, Epoch Accuracy: 63.950, Validation Loss: 1.220,Validation Accuracy: 58.346
# Epoch: 32
# Training Data: Epoch Loss: 1.278, Epoch Accuracy: 58.053, Validation Loss: 1.300,Validation Accuracy: 55.403
# Epoch: 33
# Training Data: Epoch Loss: 1.161, Epoch Accuracy: 60.972, Validation Loss: 1.051,Validation Accuracy: 64.587
# Epoch: 34
# Training Data: Epoch Loss: 1.132, Epoch Accuracy: 62.247, Validation Loss: 1.603,Validation Accuracy: 54.033
# Epoch: 35
# Training Data: Epoch Loss: 1.280, Epoch Accuracy: 57.748, Validation Loss: 1.768,Validation Accuracy: 46.829
# Epoch: 36
# Training Data: Epoch Loss: 1.256, Epoch Accuracy: 58.045, Validation Loss: 1.684,Validation Accuracy: 50.482
# Epoch: 37
# Training Data: Epoch Loss: 1.407, Epoch Accuracy: 53.706, Validation Loss: 6.436,Validation Accuracy: 10.857
# Epoch: 38
# Training Data: Epoch Loss: 1.339, Epoch Accuracy: 56.343, Validation Loss: 2.256,Validation Accuracy: 34.399
# Epoch: 39
# Training Data: Epoch Loss: 1.287, Epoch Accuracy: 57.980, Validation Loss: 7.235,Validation Accuracy: 9.031
# Epoch: 40
# Training Data: Epoch Loss: 1.530, Epoch Accuracy: 51.047, Validation Loss: 1.550,Validation Accuracy: 52.410
# Epoch: 41
# Training Data: Epoch Loss: 1.306, Epoch Accuracy: 57.734, Validation Loss: 1.356,Validation Accuracy: 54.997
# Epoch: 42
# Training Data: Epoch Loss: 1.389, Epoch Accuracy: 56.154, Validation Loss: 3.166,Validation Accuracy: 32.420
# Epoch: 43
# Training Data: Epoch Loss: 2.671, Epoch Accuracy: 30.595, Validation Loss: 2.643,Validation Accuracy: 32.420
# Epoch: 44
# Training Data: Epoch Loss: 2.663, Epoch Accuracy: 30.406, Validation Loss: 2.611,Validation Accuracy: 32.420
# Epoch: 45
# Training Data: Epoch Loss: 2.664, Epoch Accuracy: 30.406, Validation Loss: 2.612,Validation Accuracy: 32.420
# Epoch: 46
# Training Data: Epoch Loss: 2.658, Epoch Accuracy: 30.406, Validation Loss: 2.635,Validation Accuracy: 32.420
# Epoch: 47
# Training Data: Epoch Loss: 2.659, Epoch Accuracy: 30.406, Validation Loss: 2.644,Validation Accuracy: 32.420
# Epoch: 48
# Training Data: Epoch Loss: 2.656, Epoch Accuracy: 30.406, Validation Loss: 2.613,Validation Accuracy: 32.420
# Epoch: 49
# Training Data: Epoch Loss: 2.655, Epoch Accuracy: 30.406, Validation Loss: 2.612,Validation Accuracy: 32.420
# Epoch: 50
# Training Data: Epoch Loss: 2.653, Epoch Accuracy: 30.406, Validation Loss: 2.612,Validation Accuracy: 32.420
# ######## epoch Finished in 7359.124706029892 seconds ###########
# Learning Rate: 0.1000
# Batch Size: 64
# Epoch size: 50
# Epoch: 1
# Training Data: Epoch Loss: 2.009, Epoch Accuracy: 43.679, Validation Loss: 1.488,Validation Accuracy: 56.317
# Epoch: 2
# Training Data: Epoch Loss: 0.977, Epoch Accuracy: 67.420, Validation Loss: 1.170,Validation Accuracy: 63.521
# Epoch: 3
# Training Data: Epoch Loss: 0.645, Epoch Accuracy: 78.367, Validation Loss: 0.684,Validation Accuracy: 77.829
# Epoch: 4
# Training Data: Epoch Loss: 0.435, Epoch Accuracy: 85.337, Validation Loss: 0.981,Validation Accuracy: 73.820
# Epoch: 5
# Training Data: Epoch Loss: 0.327, Epoch Accuracy: 89.285, Validation Loss: 0.444,Validation Accuracy: 85.185
# Epoch: 6
# Training Data: Epoch Loss: 0.243, Epoch Accuracy: 91.690, Validation Loss: 0.173,Validation Accuracy: 94.521
# Epoch: 7
# Training Data: Epoch Loss: 0.182, Epoch Accuracy: 93.871, Validation Loss: 0.200,Validation Accuracy: 92.745
# Epoch: 8
# Training Data: Epoch Loss: 0.136, Epoch Accuracy: 95.327, Validation Loss: 0.177,Validation Accuracy: 94.470
# Epoch: 9
# Training Data: Epoch Loss: 0.112, Epoch Accuracy: 96.153, Validation Loss: 0.300,Validation Accuracy: 91.527
# Epoch: 10
# Training Data: Epoch Loss: 0.087, Epoch Accuracy: 97.146, Validation Loss: 0.102,Validation Accuracy: 96.550
# Epoch: 11
# Training Data: Epoch Loss: 0.061, Epoch Accuracy: 97.892, Validation Loss: 0.084,Validation Accuracy: 97.666
# Epoch: 12
# Training Data: Epoch Loss: 0.052, Epoch Accuracy: 98.225, Validation Loss: 0.168,Validation Accuracy: 94.521
# Epoch: 13
# Training Data: Epoch Loss: 0.029, Epoch Accuracy: 98.986, Validation Loss: 0.086,Validation Accuracy: 97.463
# Epoch: 14
# Training Data: Epoch Loss: 0.029, Epoch Accuracy: 99.087, Validation Loss: 0.052,Validation Accuracy: 98.529
# Epoch: 15
# Training Data: Epoch Loss: 0.024, Epoch Accuracy: 99.210, Validation Loss: 0.040,Validation Accuracy: 98.630
# Epoch: 16
# Training Data: Epoch Loss: 0.016, Epoch Accuracy: 99.442, Validation Loss: 0.052,Validation Accuracy: 98.529
# Epoch: 17
# Training Data: Epoch Loss: 0.012, Epoch Accuracy: 99.659, Validation Loss: 0.040,Validation Accuracy: 98.884
# Epoch: 18
# Training Data: Epoch Loss: 0.011, Epoch Accuracy: 99.631, Validation Loss: 0.038,Validation Accuracy: 98.681
# Epoch: 19
# Training Data: Epoch Loss: 0.010, Epoch Accuracy: 99.710, Validation Loss: 0.042,Validation Accuracy: 98.376
# Epoch: 20
# Training Data: Epoch Loss: 0.011, Epoch Accuracy: 99.681, Validation Loss: 0.042,Validation Accuracy: 98.884
# Epoch: 21
# Training Data: Epoch Loss: 0.012, Epoch Accuracy: 99.688, Validation Loss: 0.047,Validation Accuracy: 98.630
# Epoch: 22
# Training Data: Epoch Loss: 0.010, Epoch Accuracy: 99.739, Validation Loss: 0.036,Validation Accuracy: 98.833
# Epoch: 23
# Training Data: Epoch Loss: 0.010, Epoch Accuracy: 99.688, Validation Loss: 0.047,Validation Accuracy: 98.681
# Epoch: 24
# Training Data: Epoch Loss: 0.011, Epoch Accuracy: 99.631, Validation Loss: 0.040,Validation Accuracy: 98.529
# Epoch: 25
# Training Data: Epoch Loss: 0.009, Epoch Accuracy: 99.739, Validation Loss: 0.045,Validation Accuracy: 98.579
# Epoch: 26
# Training Data: Epoch Loss: 0.012, Epoch Accuracy: 99.551, Validation Loss: 0.041,Validation Accuracy: 98.985
# Epoch: 27
# Training Data: Epoch Loss: 0.012, Epoch Accuracy: 99.573, Validation Loss: 0.053,Validation Accuracy: 98.224
# Epoch: 28
# Training Data: Epoch Loss: 0.022, Epoch Accuracy: 99.268, Validation Loss: 0.046,Validation Accuracy: 98.529
# Epoch: 29
# Training Data: Epoch Loss: 0.027, Epoch Accuracy: 99.036, Validation Loss: 0.080,Validation Accuracy: 97.818
# Epoch: 30
# Training Data: Epoch Loss: 0.028, Epoch Accuracy: 99.044, Validation Loss: 0.084,Validation Accuracy: 97.565
# Epoch: 31
# Training Data: Epoch Loss: 0.042, Epoch Accuracy: 98.652, Validation Loss: 0.101,Validation Accuracy: 97.108
# Epoch: 32
# Training Data: Epoch Loss: 0.051, Epoch Accuracy: 98.283, Validation Loss: 0.180,Validation Accuracy: 94.926
# Epoch: 33
# Training Data: Epoch Loss: 0.062, Epoch Accuracy: 97.848, Validation Loss: 0.420,Validation Accuracy: 88.838
# Epoch: 34
# Training Data: Epoch Loss: 0.075, Epoch Accuracy: 97.312, Validation Loss: 0.116,Validation Accuracy: 96.854
# Epoch: 35
# Training Data: Epoch Loss: 0.075, Epoch Accuracy: 97.479, Validation Loss: 0.180,Validation Accuracy: 94.774
# Epoch: 36
# Training Data: Epoch Loss: 0.078, Epoch Accuracy: 97.370, Validation Loss: 0.198,Validation Accuracy: 93.557
# Epoch: 37
# Training Data: Epoch Loss: 0.071, Epoch Accuracy: 97.551, Validation Loss: 0.273,Validation Accuracy: 92.187
# Epoch: 38
# Training Data: Epoch Loss: 0.074, Epoch Accuracy: 97.443, Validation Loss: 0.165,Validation Accuracy: 94.470
# Epoch: 39
# Training Data: Epoch Loss: 0.069, Epoch Accuracy: 97.682, Validation Loss: 0.386,Validation Accuracy: 89.802
# Epoch: 40
# Training Data: Epoch Loss: 0.069, Epoch Accuracy: 97.747, Validation Loss: 0.142,Validation Accuracy: 95.586
# Epoch: 41
# Training Data: Epoch Loss: 0.069, Epoch Accuracy: 97.747, Validation Loss: 0.118,Validation Accuracy: 96.550
# Epoch: 42
# Training Data: Epoch Loss: 0.051, Epoch Accuracy: 98.334, Validation Loss: 0.177,Validation Accuracy: 94.521
# Epoch: 43
# Training Data: Epoch Loss: 0.040, Epoch Accuracy: 98.609, Validation Loss: 0.097,Validation Accuracy: 97.514
# Epoch: 44
# Training Data: Epoch Loss: 0.044, Epoch Accuracy: 98.464, Validation Loss: 0.150,Validation Accuracy: 95.231
# Epoch: 45
# Training Data: Epoch Loss: 0.034, Epoch Accuracy: 98.993, Validation Loss: 0.097,Validation Accuracy: 97.159
# Epoch: 46
# Training Data: Epoch Loss: 0.030, Epoch Accuracy: 99.029, Validation Loss: 0.095,Validation Accuracy: 97.210
# Epoch: 47
# Training Data: Epoch Loss: 0.021, Epoch Accuracy: 99.355, Validation Loss: 0.036,Validation Accuracy: 98.681
# Epoch: 48
# Training Data: Epoch Loss: 0.013, Epoch Accuracy: 99.551, Validation Loss: 0.034,Validation Accuracy: 98.935
# Epoch: 49
# Training Data: Epoch Loss: 0.011, Epoch Accuracy: 99.645, Validation Loss: 0.048,Validation Accuracy: 98.376
# Epoch: 50
# Training Data: Epoch Loss: 0.008, Epoch Accuracy: 99.725, Validation Loss: 0.029,Validation Accuracy: 99.036
# ######## epoch Finished in 7468.083228111267 seconds ###########
# Learning Rate: 0.0100
# Batch Size: 64
# Epoch size: 50
# Epoch: 1
# Training Data: Epoch Loss: 1.640, Epoch Accuracy: 48.316, Validation Loss: 1.139,Validation Accuracy: 61.238
# Epoch: 2
# Training Data: Epoch Loss: 0.631, Epoch Accuracy: 78.628, Validation Loss: 0.574,Validation Accuracy: 79.959
# Epoch: 3
# Training Data: Epoch Loss: 0.344, Epoch Accuracy: 88.416, Validation Loss: 1.068,Validation Accuracy: 72.653
# Epoch: 4
# Training Data: Epoch Loss: 0.238, Epoch Accuracy: 91.973, Validation Loss: 0.279,Validation Accuracy: 90.411
# Epoch: 5
# Training Data: Epoch Loss: 0.170, Epoch Accuracy: 94.364, Validation Loss: 0.796,Validation Accuracy: 78.691
# Epoch: 6
# Training Data: Epoch Loss: 0.134, Epoch Accuracy: 95.610, Validation Loss: 0.823,Validation Accuracy: 81.481
# Epoch: 7
# Training Data: Epoch Loss: 0.096, Epoch Accuracy: 96.783, Validation Loss: 0.118,Validation Accuracy: 95.840
# Epoch: 8
# Training Data: Epoch Loss: 0.073, Epoch Accuracy: 97.551, Validation Loss: 0.134,Validation Accuracy: 95.535
# Epoch: 9
# Training Data: Epoch Loss: 0.057, Epoch Accuracy: 98.167, Validation Loss: 0.066,Validation Accuracy: 97.768
# Epoch: 10
# Training Data: Epoch Loss: 0.043, Epoch Accuracy: 98.464, Validation Loss: 0.108,Validation Accuracy: 96.347
# Epoch: 11
# Training Data: Epoch Loss: 0.037, Epoch Accuracy: 98.826, Validation Loss: 0.056,Validation Accuracy: 97.818
# Epoch: 12
# Training Data: Epoch Loss: 0.029, Epoch Accuracy: 99.116, Validation Loss: 0.044,Validation Accuracy: 98.681
# Epoch: 13
# Training Data: Epoch Loss: 0.024, Epoch Accuracy: 99.276, Validation Loss: 0.043,Validation Accuracy: 98.529
# Epoch: 14
# Training Data: Epoch Loss: 0.019, Epoch Accuracy: 99.449, Validation Loss: 0.044,Validation Accuracy: 98.630
# Epoch: 15
# Training Data: Epoch Loss: 0.015, Epoch Accuracy: 99.558, Validation Loss: 0.036,Validation Accuracy: 98.732
# Epoch: 16
# Training Data: Epoch Loss: 0.013, Epoch Accuracy: 99.659, Validation Loss: 0.041,Validation Accuracy: 98.782
# Epoch: 17
# Training Data: Epoch Loss: 0.012, Epoch Accuracy: 99.703, Validation Loss: 0.029,Validation Accuracy: 98.935
# Epoch: 18
# Training Data: Epoch Loss: 0.012, Epoch Accuracy: 99.696, Validation Loss: 0.026,Validation Accuracy: 99.036
# Epoch: 19
# Training Data: Epoch Loss: 0.010, Epoch Accuracy: 99.754, Validation Loss: 0.035,Validation Accuracy: 98.782
# Epoch: 20
# Training Data: Epoch Loss: 0.010, Epoch Accuracy: 99.833, Validation Loss: 0.029,Validation Accuracy: 99.036
# Epoch: 21
# Training Data: Epoch Loss: 0.010, Epoch Accuracy: 99.746, Validation Loss: 0.029,Validation Accuracy: 99.137
# Epoch: 22
# Training Data: Epoch Loss: 0.009, Epoch Accuracy: 99.804, Validation Loss: 0.033,Validation Accuracy: 98.935
# Epoch: 23
# Training Data: Epoch Loss: 0.011, Epoch Accuracy: 99.696, Validation Loss: 0.039,Validation Accuracy: 98.681
# Epoch: 24
# Training Data: Epoch Loss: 0.010, Epoch Accuracy: 99.768, Validation Loss: 0.033,Validation Accuracy: 98.833
# Epoch: 25
# Training Data: Epoch Loss: 0.010, Epoch Accuracy: 99.775, Validation Loss: 0.029,Validation Accuracy: 98.884
# Epoch: 26
# Training Data: Epoch Loss: 0.010, Epoch Accuracy: 99.783, Validation Loss: 0.028,Validation Accuracy: 98.935
# Epoch: 27
# Training Data: Epoch Loss: 0.012, Epoch Accuracy: 99.674, Validation Loss: 0.032,Validation Accuracy: 98.732
# Epoch: 28
# Training Data: Epoch Loss: 0.011, Epoch Accuracy: 99.746, Validation Loss: 0.031,Validation Accuracy: 98.985
# Epoch: 29
# Training Data: Epoch Loss: 0.013, Epoch Accuracy: 99.573, Validation Loss: 0.042,Validation Accuracy: 98.681
# Epoch: 30
# Training Data: Epoch Loss: 0.014, Epoch Accuracy: 99.573, Validation Loss: 0.035,Validation Accuracy: 98.935
# Epoch: 31
# Training Data: Epoch Loss: 0.018, Epoch Accuracy: 99.464, Validation Loss: 0.048,Validation Accuracy: 98.630
# Epoch: 32
# Training Data: Epoch Loss: 0.024, Epoch Accuracy: 99.181, Validation Loss: 0.043,Validation Accuracy: 98.579
# Epoch: 33
# Training Data: Epoch Loss: 0.028, Epoch Accuracy: 99.022, Validation Loss: 0.063,Validation Accuracy: 98.021
# Epoch: 34
# Training Data: Epoch Loss: 0.037, Epoch Accuracy: 98.732, Validation Loss: 0.076,Validation Accuracy: 97.565
# Epoch: 35
# Training Data: Epoch Loss: 0.048, Epoch Accuracy: 98.399, Validation Loss: 0.137,Validation Accuracy: 95.332
# Epoch: 36
# Training Data: Epoch Loss: 0.055, Epoch Accuracy: 98.225, Validation Loss: 0.235,Validation Accuracy: 93.201
# Epoch: 37
# Training Data: Epoch Loss: 0.042, Epoch Accuracy: 98.587, Validation Loss: 0.167,Validation Accuracy: 96.093
# Epoch: 38
# Training Data: Epoch Loss: 0.048, Epoch Accuracy: 98.384, Validation Loss: 0.078,Validation Accuracy: 97.818
# Epoch: 39
# Training Data: Epoch Loss: 0.037, Epoch Accuracy: 98.812, Validation Loss: 0.079,Validation Accuracy: 98.021
# Epoch: 40
# Training Data: Epoch Loss: 0.042, Epoch Accuracy: 98.660, Validation Loss: 0.225,Validation Accuracy: 92.796
# Epoch: 41
# Training Data: Epoch Loss: 0.037, Epoch Accuracy: 98.739, Validation Loss: 0.090,Validation Accuracy: 97.463
# Epoch: 42
# Training Data: Epoch Loss: 0.040, Epoch Accuracy: 98.652, Validation Loss: 0.318,Validation Accuracy: 91.071
# Epoch: 43
# Training Data: Epoch Loss: 0.034, Epoch Accuracy: 98.776, Validation Loss: 0.118,Validation Accuracy: 96.195
# Epoch: 44
# Training Data: Epoch Loss: 0.026, Epoch Accuracy: 99.167, Validation Loss: 0.038,Validation Accuracy: 98.782
# Epoch: 45
# Training Data: Epoch Loss: 0.023, Epoch Accuracy: 99.189, Validation Loss: 0.051,Validation Accuracy: 98.427
# Epoch: 46
# Training Data: Epoch Loss: 0.013, Epoch Accuracy: 99.602, Validation Loss: 0.046,Validation Accuracy: 98.529
# Epoch: 47
# Training Data: Epoch Loss: 0.014, Epoch Accuracy: 99.493, Validation Loss: 0.031,Validation Accuracy: 98.935
# Epoch: 48
# Training Data: Epoch Loss: 0.009, Epoch Accuracy: 99.717, Validation Loss: 0.035,Validation Accuracy: 98.833
# Epoch: 49
# Training Data: Epoch Loss: 0.007, Epoch Accuracy: 99.841, Validation Loss: 0.037,Validation Accuracy: 98.630
# Epoch: 50
# Training Data: Epoch Loss: 0.004, Epoch Accuracy: 99.906, Validation Loss: 0.019,Validation Accuracy: 99.340
# ######## epoch Finished in 7325.211688995361 seconds ###########
# Learning Rate: 0.0010
# Batch Size: 64
# Epoch size: 50
# Epoch: 1
# Training Data: Epoch Loss: 2.389, Epoch Accuracy: 32.913, Validation Loss: 2.057,Validation Accuracy: 36.885
# Epoch: 2
# Training Data: Epoch Loss: 1.875, Epoch Accuracy: 42.027, Validation Loss: 1.655,Validation Accuracy: 49.011
# Epoch: 3
# Training Data: Epoch Loss: 1.432, Epoch Accuracy: 54.416, Validation Loss: 1.298,Validation Accuracy: 56.875
# Epoch: 4
# Training Data: Epoch Loss: 1.098, Epoch Accuracy: 64.609, Validation Loss: 1.022,Validation Accuracy: 65.703
# Epoch: 5
# Training Data: Epoch Loss: 0.845, Epoch Accuracy: 73.013, Validation Loss: 0.840,Validation Accuracy: 72.045
# Epoch: 6
# Training Data: Epoch Loss: 0.665, Epoch Accuracy: 78.650, Validation Loss: 0.590,Validation Accuracy: 81.735
# Epoch: 7
# Training Data: Epoch Loss: 0.535, Epoch Accuracy: 83.083, Validation Loss: 0.510,Validation Accuracy: 83.866
# Epoch: 8
# Training Data: Epoch Loss: 0.439, Epoch Accuracy: 86.220, Validation Loss: 0.361,Validation Accuracy: 89.295
# Epoch: 9
# Training Data: Epoch Loss: 0.377, Epoch Accuracy: 88.401, Validation Loss: 0.520,Validation Accuracy: 82.141
# Epoch: 10
# Training Data: Epoch Loss: 0.319, Epoch Accuracy: 90.031, Validation Loss: 0.305,Validation Accuracy: 90.360
# Epoch: 11
# Training Data: Epoch Loss: 0.273, Epoch Accuracy: 91.792, Validation Loss: 0.266,Validation Accuracy: 92.085
# Epoch: 12
# Training Data: Epoch Loss: 0.240, Epoch Accuracy: 92.762, Validation Loss: 0.236,Validation Accuracy: 92.440
# Epoch: 13
# Training Data: Epoch Loss: 0.213, Epoch Accuracy: 93.704, Validation Loss: 0.212,Validation Accuracy: 93.354
# Epoch: 14
# Training Data: Epoch Loss: 0.195, Epoch Accuracy: 94.197, Validation Loss: 0.176,Validation Accuracy: 94.267
# Epoch: 15
# Training Data: Epoch Loss: 0.185, Epoch Accuracy: 94.364, Validation Loss: 0.166,Validation Accuracy: 94.825
# Epoch: 16
# Training Data: Epoch Loss: 0.176, Epoch Accuracy: 94.617, Validation Loss: 0.164,Validation Accuracy: 94.825
# Epoch: 17
# Training Data: Epoch Loss: 0.164, Epoch Accuracy: 95.197, Validation Loss: 0.159,Validation Accuracy: 95.332
# Epoch: 18
# Training Data: Epoch Loss: 0.157, Epoch Accuracy: 95.450, Validation Loss: 0.129,Validation Accuracy: 96.449
# Epoch: 19
# Training Data: Epoch Loss: 0.148, Epoch Accuracy: 95.813, Validation Loss: 0.122,Validation Accuracy: 96.398
# Epoch: 20
# Training Data: Epoch Loss: 0.147, Epoch Accuracy: 95.841, Validation Loss: 0.125,Validation Accuracy: 96.043
# Epoch: 21
# Training Data: Epoch Loss: 0.143, Epoch Accuracy: 95.870, Validation Loss: 0.131,Validation Accuracy: 96.093
# Epoch: 22
# Training Data: Epoch Loss: 0.147, Epoch Accuracy: 95.755, Validation Loss: 0.120,Validation Accuracy: 96.296
# Epoch: 23
# Training Data: Epoch Loss: 0.139, Epoch Accuracy: 95.841, Validation Loss: 0.123,Validation Accuracy: 96.449
# Epoch: 24
# Training Data: Epoch Loss: 0.139, Epoch Accuracy: 96.037, Validation Loss: 0.132,Validation Accuracy: 96.601
# Epoch: 25
# Training Data: Epoch Loss: 0.135, Epoch Accuracy: 96.240, Validation Loss: 0.136,Validation Accuracy: 95.789
# Epoch: 26
# Training Data: Epoch Loss: 0.134, Epoch Accuracy: 96.008, Validation Loss: 0.118,Validation Accuracy: 96.246
# Epoch: 27
# Training Data: Epoch Loss: 0.135, Epoch Accuracy: 95.863, Validation Loss: 0.132,Validation Accuracy: 96.398
# Epoch: 28
# Training Data: Epoch Loss: 0.136, Epoch Accuracy: 95.965, Validation Loss: 0.129,Validation Accuracy: 96.246
# Epoch: 29
# Training Data: Epoch Loss: 0.135, Epoch Accuracy: 95.986, Validation Loss: 0.126,Validation Accuracy: 95.840
# Epoch: 30
# Training Data: Epoch Loss: 0.132, Epoch Accuracy: 95.914, Validation Loss: 0.149,Validation Accuracy: 95.332
# Epoch: 31
# Training Data: Epoch Loss: 0.130, Epoch Accuracy: 95.914, Validation Loss: 0.301,Validation Accuracy: 90.360
# Epoch: 32
# Training Data: Epoch Loss: 0.127, Epoch Accuracy: 96.189, Validation Loss: 0.226,Validation Accuracy: 92.288
# Epoch: 33
# Training Data: Epoch Loss: 0.121, Epoch Accuracy: 96.153, Validation Loss: 0.163,Validation Accuracy: 94.571
# Epoch: 34
# Training Data: Epoch Loss: 0.121, Epoch Accuracy: 96.298, Validation Loss: 0.234,Validation Accuracy: 91.730
# Epoch: 35
# Training Data: Epoch Loss: 0.124, Epoch Accuracy: 96.124, Validation Loss: 0.121,Validation Accuracy: 95.992
# Epoch: 36
# Training Data: Epoch Loss: 0.116, Epoch Accuracy: 96.349, Validation Loss: 0.329,Validation Accuracy: 90.411
# Epoch: 37
# Training Data: Epoch Loss: 0.107, Epoch Accuracy: 96.551, Validation Loss: 0.174,Validation Accuracy: 93.760
# Epoch: 38
# Training Data: Epoch Loss: 0.102, Epoch Accuracy: 96.827, Validation Loss: 0.208,Validation Accuracy: 92.998
# Epoch: 39
# Training Data: Epoch Loss: 0.112, Epoch Accuracy: 96.631, Validation Loss: 0.100,Validation Accuracy: 96.601
# Epoch: 40
# Training Data: Epoch Loss: 0.092, Epoch Accuracy: 97.080, Validation Loss: 0.128,Validation Accuracy: 96.347
# Epoch: 41
# Training Data: Epoch Loss: 0.091, Epoch Accuracy: 97.102, Validation Loss: 0.158,Validation Accuracy: 94.926
# Epoch: 42
# Training Data: Epoch Loss: 0.083, Epoch Accuracy: 97.559, Validation Loss: 0.176,Validation Accuracy: 93.861
# Epoch: 43
# Training Data: Epoch Loss: 0.080, Epoch Accuracy: 97.580, Validation Loss: 0.134,Validation Accuracy: 95.282
# Epoch: 44
# Training Data: Epoch Loss: 0.071, Epoch Accuracy: 97.841, Validation Loss: 0.129,Validation Accuracy: 95.586
# Epoch: 45
# Training Data: Epoch Loss: 0.061, Epoch Accuracy: 98.211, Validation Loss: 0.132,Validation Accuracy: 95.687
# Epoch: 46
# Training Data: Epoch Loss: 0.055, Epoch Accuracy: 98.413, Validation Loss: 0.093,Validation Accuracy: 97.260
# Epoch: 47
# Training Data: Epoch Loss: 0.052, Epoch Accuracy: 98.450, Validation Loss: 0.167,Validation Accuracy: 94.825
# Epoch: 48
# Training Data: Epoch Loss: 0.048, Epoch Accuracy: 98.645, Validation Loss: 0.076,Validation Accuracy: 97.362
# Epoch: 49
# Training Data: Epoch Loss: 0.044, Epoch Accuracy: 98.776, Validation Loss: 0.064,Validation Accuracy: 98.072
# Epoch: 50
# Training Data: Epoch Loss: 0.044, Epoch Accuracy: 98.566, Validation Loss: 0.073,Validation Accuracy: 97.971
# ######## epoch Finished in 7375.998961210251 seconds ###########
# Learning Rate: 0.0001
# Batch Size: 64
# Epoch size: 50
# Epoch: 1
# Training Data: Epoch Loss: 2.672, Epoch Accuracy: 28.023, Validation Loss: 2.539,Validation Accuracy: 32.420
# Epoch: 2
# Training Data: Epoch Loss: 2.551, Epoch Accuracy: 30.406, Validation Loss: 2.482,Validation Accuracy: 32.420
# Epoch: 3
# Training Data: Epoch Loss: 2.473, Epoch Accuracy: 30.957, Validation Loss: 2.396,Validation Accuracy: 34.500
# Epoch: 4
# Training Data: Epoch Loss: 2.383, Epoch Accuracy: 33.804, Validation Loss: 2.301,Validation Accuracy: 35.312
# Epoch: 5
# Training Data: Epoch Loss: 2.307, Epoch Accuracy: 34.072, Validation Loss: 2.236,Validation Accuracy: 35.718
# Epoch: 6
# Training Data: Epoch Loss: 2.243, Epoch Accuracy: 34.377, Validation Loss: 2.169,Validation Accuracy: 35.413
# Epoch: 7
# Training Data: Epoch Loss: 2.179, Epoch Accuracy: 34.536, Validation Loss: 2.102,Validation Accuracy: 36.631
# Epoch: 8
# Training Data: Epoch Loss: 2.120, Epoch Accuracy: 35.688, Validation Loss: 2.043,Validation Accuracy: 37.494
# Epoch: 9
# Training Data: Epoch Loss: 2.056, Epoch Accuracy: 37.289, Validation Loss: 1.985,Validation Accuracy: 38.864
# Epoch: 10
# Training Data: Epoch Loss: 1.992, Epoch Accuracy: 38.434, Validation Loss: 1.914,Validation Accuracy: 42.212
# Epoch: 11
# Training Data: Epoch Loss: 1.926, Epoch Accuracy: 40.259, Validation Loss: 1.848,Validation Accuracy: 42.618
# Epoch: 12
# Training Data: Epoch Loss: 1.866, Epoch Accuracy: 41.455, Validation Loss: 1.781,Validation Accuracy: 44.394
# Epoch: 13
# Training Data: Epoch Loss: 1.802, Epoch Accuracy: 43.034, Validation Loss: 1.716,Validation Accuracy: 45.408
# Epoch: 14
# Training Data: Epoch Loss: 1.730, Epoch Accuracy: 45.179, Validation Loss: 1.658,Validation Accuracy: 48.554
# Epoch: 15
# Training Data: Epoch Loss: 1.670, Epoch Accuracy: 47.584, Validation Loss: 1.573,Validation Accuracy: 51.649
# Epoch: 16
# Training Data: Epoch Loss: 1.609, Epoch Accuracy: 49.178, Validation Loss: 1.542,Validation Accuracy: 53.120
# Epoch: 17
# Training Data: Epoch Loss: 1.550, Epoch Accuracy: 50.757, Validation Loss: 1.477,Validation Accuracy: 53.222
# Epoch: 18
# Training Data: Epoch Loss: 1.506, Epoch Accuracy: 51.742, Validation Loss: 1.451,Validation Accuracy: 52.816
# Epoch: 19
# Training Data: Epoch Loss: 1.456, Epoch Accuracy: 53.228, Validation Loss: 1.375,Validation Accuracy: 56.418
# Epoch: 20
# Training Data: Epoch Loss: 1.404, Epoch Accuracy: 54.351, Validation Loss: 1.345,Validation Accuracy: 57.382
# Epoch: 21
# Training Data: Epoch Loss: 1.356, Epoch Accuracy: 56.147, Validation Loss: 1.302,Validation Accuracy: 58.194
# Epoch: 22
# Training Data: Epoch Loss: 1.325, Epoch Accuracy: 56.205, Validation Loss: 1.280,Validation Accuracy: 59.107
# Epoch: 23
# Training Data: Epoch Loss: 1.266, Epoch Accuracy: 59.183, Validation Loss: 1.186,Validation Accuracy: 63.876
# Epoch: 24
# Training Data: Epoch Loss: 1.222, Epoch Accuracy: 61.248, Validation Loss: 1.160,Validation Accuracy: 63.115
# Epoch: 25
# Training Data: Epoch Loss: 1.183, Epoch Accuracy: 61.798, Validation Loss: 1.115,Validation Accuracy: 65.195
# Epoch: 26
# Training Data: Epoch Loss: 1.131, Epoch Accuracy: 64.008, Validation Loss: 1.086,Validation Accuracy: 64.992
# Epoch: 27
# Training Data: Epoch Loss: 1.102, Epoch Accuracy: 64.747, Validation Loss: 1.055,Validation Accuracy: 67.631
# Epoch: 28
# Training Data: Epoch Loss: 1.049, Epoch Accuracy: 66.964, Validation Loss: 0.970,Validation Accuracy: 70.523
# Epoch: 29
# Training Data: Epoch Loss: 1.011, Epoch Accuracy: 67.529, Validation Loss: 0.969,Validation Accuracy: 69.153
# Epoch: 30
# Training Data: Epoch Loss: 0.978, Epoch Accuracy: 69.101, Validation Loss: 0.924,Validation Accuracy: 71.030
# Epoch: 31
# Training Data: Epoch Loss: 0.929, Epoch Accuracy: 70.362, Validation Loss: 0.860,Validation Accuracy: 72.806
# Epoch: 32
# Training Data: Epoch Loss: 0.917, Epoch Accuracy: 70.405, Validation Loss: 0.832,Validation Accuracy: 72.907
# Epoch: 33
# Training Data: Epoch Loss: 0.883, Epoch Accuracy: 71.231, Validation Loss: 0.821,Validation Accuracy: 72.806
# Epoch: 34
# Training Data: Epoch Loss: 0.857, Epoch Accuracy: 72.115, Validation Loss: 0.817,Validation Accuracy: 73.973
# Epoch: 35
# Training Data: Epoch Loss: 0.821, Epoch Accuracy: 72.991, Validation Loss: 0.770,Validation Accuracy: 74.226
# Epoch: 36
# Training Data: Epoch Loss: 0.798, Epoch Accuracy: 73.854, Validation Loss: 0.768,Validation Accuracy: 74.937
# Epoch: 37
# Training Data: Epoch Loss: 0.766, Epoch Accuracy: 75.027, Validation Loss: 0.745,Validation Accuracy: 75.901
# Epoch: 38
# Training Data: Epoch Loss: 0.738, Epoch Accuracy: 76.505, Validation Loss: 0.739,Validation Accuracy: 74.835
# Epoch: 39
# Training Data: Epoch Loss: 0.713, Epoch Accuracy: 77.324, Validation Loss: 0.646,Validation Accuracy: 80.467
# Epoch: 40
# Training Data: Epoch Loss: 0.690, Epoch Accuracy: 78.244, Validation Loss: 0.632,Validation Accuracy: 80.873
# Epoch: 41
# Training Data: Epoch Loss: 0.666, Epoch Accuracy: 79.113, Validation Loss: 0.597,Validation Accuracy: 82.243
# Epoch: 42
# Training Data: Epoch Loss: 0.643, Epoch Accuracy: 79.446, Validation Loss: 0.606,Validation Accuracy: 80.518
# Epoch: 43
# Training Data: Epoch Loss: 0.629, Epoch Accuracy: 80.352, Validation Loss: 0.580,Validation Accuracy: 81.329
# Epoch: 44
# Training Data: Epoch Loss: 0.611, Epoch Accuracy: 80.569, Validation Loss: 0.579,Validation Accuracy: 82.090
# Epoch: 45
# Training Data: Epoch Loss: 0.578, Epoch Accuracy: 81.917, Validation Loss: 0.560,Validation Accuracy: 82.648
# Epoch: 46
# Training Data: Epoch Loss: 0.564, Epoch Accuracy: 82.366, Validation Loss: 0.556,Validation Accuracy: 82.395
# Epoch: 47
# Training Data: Epoch Loss: 0.550, Epoch Accuracy: 82.844, Validation Loss: 0.493,Validation Accuracy: 85.591
# Epoch: 48
# Training Data: Epoch Loss: 0.525, Epoch Accuracy: 83.967, Validation Loss: 0.481,Validation Accuracy: 85.895
# Epoch: 49
# Training Data: Epoch Loss: 0.513, Epoch Accuracy: 84.293, Validation Loss: 0.458,Validation Accuracy: 86.707
# Epoch: 50
# Training Data: Epoch Loss: 0.493, Epoch Accuracy: 84.808, Validation Loss: 0.527,Validation Accuracy: 83.308
# ######## epoch Finished in 7385.728714942932 seconds ###########

# %%
plt.plot(range(5),lr_accuract_training, label="Training")
plt.plot(range(5),lr_accuracy_val, label="Validation")
plt.xlabel("Folds")
plt.ylabel("Accuracies")
plt.title("Training vs Validation vs Test Accuracies with learning rate")
plt.legend()
plt.show()

# %%
plt.plot(range(5),lr_loss_train, label="Training")
plt.plot(range(5),lr_loss_val, label="Validation")
plt.xlabel("Folds")
plt.ylabel("Accuracies")
plt.title("Training vs Validation vs Test Loss with learning rate")
plt.legend()
plt.show()

# %%
print(best_param)
# Out:
# Learning Rate: 0.01 Batch Size: 64

# %%
model_path = 'best_checkpoint.model'

# %%
model = models.mobilenet_v2(pretrained=False, num_classes = 20)
model.to(device)
# Out:
# MobileNetV2(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): Conv2dNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1280, out_features=20, bias=True)
#   )
# )

# %%
state_dict = torch.load(model_path)

# %%
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
testing_loader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
def evaluate_model(model,test_loader):
    model.eval()
    predicted_correct =0
    total = 0
    with torch.no_grad():
        for data in test_loader:
            images,labels = data
            images = images.to(device)
            labels = labels.to(device)
            total+=labels.size(0)
            outputs = model(images)
            _,predicted = torch.max(outputs,1)
            predicted_correct += (predicted == labels).sum().item()
    epoch_accuracy = 100.0* predicted_correct/total
    print("Testing Data: Epoch Accuracy: %.3f"%(epoch_accuracy))
    return epoch_accuracy

# %%
evaluate_model(model,testing_loader)
# Out:
# Testing Data: Epoch Accuracy: 99.087
# 99.08745247148289

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score,ConfusionMatrixDisplay

# %%
y_pred = []
y_true = []

for data in testing_loader:
        inputs, labels = data[0].to(device), data[1].to(device)
        output = model(inputs) 
        output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
        y_pred.extend(output) 
        labels = labels.data.cpu().numpy()
        y_true.extend(labels)

# %%
confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix(y_true, y_pred),display_labels=classes)
fig,ax = plt.subplots()
fig.set_size_inches(13,13)
plt.title("Confusion Matrix InceptionV3 (20-Classes)")
disp.plot(ax=ax)
plt.xticks(rotation=45)
plt.show()

# %%
print("Precision Macro:{:.2f}".format(precision_score(y_true, y_pred, average='macro')))
print("Precision Micro:{:.2f}".format(precision_score(y_true,y_pred,average='micro')))
print("Recall Macro:{:.2f}".format(recall_score(y_true,y_pred,average='macro')))
print("Recall Micro:{:.2f}".format(recall_score(y_true,y_pred,average='micro')))
print("F1-Score Macro:{:.2f}".format(f1_score(y_true,y_pred,average='macro')))
print("F1-Score Micro:{:.2f}".format(f1_score(y_true,y_pred,average='micro')))
# Out:
# Precision Macro:0.99
# Precision Micro:0.99
# Recall Macro:0.99
# Recall Micro:0.99
# F1-Score Macro:0.99
# F1-Score Micro:0.99
