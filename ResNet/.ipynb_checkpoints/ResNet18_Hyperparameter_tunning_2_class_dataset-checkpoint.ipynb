# %%
import torch.nn as nn
import torch
import torchvision.transforms as transforms
import torchvision
import time
import matplotlib.pyplot as plt
import numpy as np
import torchvision.models as models
from sklearn.metrics import confusion_matrix
import pandas as pd
import os

# %%
def get_mean_std(loader):
    mean = 0.
    std = 0.
    total_images_count = 0
    for images,_ in loader:
        images_count_in_batch = images.size(0)
#         print(images.shape)
        images =images.view(images_count_in_batch,images.size(1),-1)
        mean+=images.mean(2).sum(0)
        std+=images.std(2).sum(0)
        total_images_count+=images_count_in_batch
    mean /= total_images_count
    std /= total_images_count
    return mean,std

# %%
def train_transform(dataset):
    train_transforms = transforms.Compose([transforms.Resize((224,224)),transforms.ToTensor()])
    train_dataset=torchvision.datasets.ImageFolder(root=dataset,transform=train_transforms)
    train_loader=torch.utils.data.DataLoader(dataset=train_dataset,batch_size=32,shuffle=True)
    mean,std=get_mean_std(train_loader)
    train_transforms = transforms.Compose([
        transforms.Resize((224,224)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(10),
        transforms.ToTensor(),
        transforms.Normalize(torch.Tensor(mean),torch.Tensor(std))
    ])
    data_set=torchvision.datasets.ImageFolder(root=dataset,transform=train_transforms)
    return data_set

# %%
train_dataset='../Datasets/dataset_2_classes/train/'
training_dataset=train_transform(train_dataset)

# %%
test_dataset='../Datasets/dataset_2_classes/test/'
testing_dataset=train_transform(test_dataset)

# %%
validate_dataset='../Datasets/dataset_2_classes/validate/'
validating_dataset=train_transform(validate_dataset)

# %%
lr = [1E-0, 1E-1, 1E-2, 1E-3, 1E-4]
Batchs=[64]

# %%
def set_device():
    device = "mps" if torch.backends.mps.is_available() else "cpu"
    return device

# %%
device=set_device()

# %%
from statistics import mean
best_accuracy=0.0
best_param=""
criterion = nn.CrossEntropyLoss()
lr_accuract_training=[]
lr_accuracy_val=[]
lr_loss_train=[]
lr_loss_val=[]

# %%
for n in lr:
    resnet18_Model = models.resnet18(pretrained=False, num_classes=2)
    resnet18_Model.to(device)
    print("Learning Rate: %.3f "%(n))
    optimizer = torch.optim.SGD(resnet18_Model.parameters(), lr=n,momentum=0.9)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=20, eta_min=0.0001)
    for Batch_size in Batchs:
        print("Batch Size: %d "%(Batch_size))
        training_loader=torch.utils.data.DataLoader(dataset=training_dataset,batch_size=Batch_size,shuffle=True,drop_last=False,num_workers=0)
        val_loader=torch.utils.data.DataLoader(dataset=validating_dataset,batch_size=Batch_size,shuffle=False,drop_last=False,num_workers=0)
        n_epochs=50
        print("Epoch size: %d "%(n_epochs))
        epoch_count = 0
        Accuracies = [] 
        valAccuracies = []
        valLoss = []
        trainLoss = []
        t1 = time.time()
        validation_accuracy = 0
        for epoch in range(n_epochs):
            print("Epoch: %d "%(epoch+1))
            resnet18_Model.train()
            running_loss=0.0
            running_correct=0.0
            val_loss=0.0
            total=0
            for i,data in enumerate(training_loader):
                images,labels=data
                images=images.to(device)
                labels=labels.to(device)
                total+=labels.size(0)
                optimizer.zero_grad()
                outputs=resnet18_Model(images)
                _,predicted=torch.max(outputs.data,1)
                loss=criterion(outputs,labels)
                loss.backward()
                optimizer.step()
                running_loss+=loss.item()
                running_correct+=(labels==predicted).sum().item()
                traning_accuracy=(running_correct/total)*100
                    
            validation_accuracy=0
            resnet18_Model.eval()
            with torch.no_grad():
                val_correct=0
                val_total=0
                val_loss=0
                for data in val_loader:
                    images,val_labels=data[0].to(device), data[1].to(device)
                    images = images.to(device)
                    val_labels = val_labels.to(device)
                    outputs=resnet18_Model(images)
                    loss_val=criterion(outputs,val_labels)
                    val_loss+= loss_val.item()
                    _,predicted=torch.max(outputs.data,1)
                    val_correct+=(predicted == val_labels).sum().item()
                    val_total+=val_labels.size(0)
                validation_accuracy = (val_correct / val_total) *100
                    
            scheduler.step()
            epoch_loss=running_loss/len(training_loader)
            val_loss=val_loss/len(val_loader)
            epoch_accuracy=100.00* running_correct/total
            Accuracies.append(epoch_accuracy)
            valAccuracies.append(validation_accuracy)
            trainLoss.append(epoch_loss)
            valLoss.append(val_loss)
                
                
            print("Training Data: Epoch Loss: %.3f, Epoch Accuracy: %.3f, Validation Loss: %.3f,Validation Accuracy: %.3f"%(epoch_loss,epoch_accuracy,val_loss,validation_accuracy))
           
        
        print("######## epoch Finished in {} seconds ###########".format(time.time()\
                                                                    -t1))
        epoch_count+=n_epochs
        torch.save(resnet18_Model.state_dict(), "2-Class-Resnet18-"+str(epoch)+"_"+str(Batch_size)+"_"+str(n)+"-epoch.pt")
            
        plt.plot(range(n_epochs),Accuracies, label="Training")
        plt.plot(range(n_epochs),valAccuracies, label="Validation")
        plt.xlabel("Folds")
        plt.ylabel("Accuracies")
        plt.title("Training vs Validation vs Test Accuracies for epoches: %d, Batch Size: %d, Learning Rate: %.3f" % (n_epochs, Batch_size, n))
        plt.legend()
        plt.show()
            
        plt.plot(range(n_epochs),trainLoss, label="Training")
        plt.plot(range(n_epochs),valLoss, label="Validation")
        plt.xlabel("Epochs")
        plt.ylabel("Loss")
        plt.title("Training vs Validation vs Test Loss for epoches: %d, Batch Size: %d, Learning Rate: %.3f" % (n_epochs, Batch_size, n))
        plt.legend()
        plt.show()
        
        lr_accuract_training.append(mean(Accuracies))
        lr_accuracy_val.append(mean(valAccuracies))
        lr_loss_train.append(mean(trainLoss))
        lr_loss_val.append(mean(valLoss))
            
        val=mean(valAccuracies)
        #Save the best model
        if val>best_accuracy:
            torch.save(resnet18_Model.state_dict(),'best_checkpoint.model')
            best_accuracy=val
            best_param="Learning Rate: "+str(n)+" Batch Size: "+str(Batch_size)+" "
# Out:
# /Users/bhanuprakash/miniforge3/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/bhanuprakash/miniforge3/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Learning Rate: 1.000
# Batch Size: 64
# Epoch size: 50
# Epoch: 1
# Training Data: Epoch Loss: 3.740, Epoch Accuracy: 77.930, Validation Loss: 313326.932,Validation Accuracy: 72.948
# Epoch: 2
# Training Data: Epoch Loss: 0.461, Epoch Accuracy: 81.152, Validation Loss: 130.358,Validation Accuracy: 72.948
# Epoch: 3
# Training Data: Epoch Loss: 0.461, Epoch Accuracy: 81.152, Validation Loss: 0.493,Validation Accuracy: 72.948
# Epoch: 4
# Training Data: Epoch Loss: 0.450, Epoch Accuracy: 81.152, Validation Loss: 0.557,Validation Accuracy: 72.948
# Epoch: 5
# Training Data: Epoch Loss: 0.446, Epoch Accuracy: 81.152, Validation Loss: 0.553,Validation Accuracy: 72.948
# Epoch: 6
# Training Data: Epoch Loss: 0.479, Epoch Accuracy: 81.152, Validation Loss: 0.500,Validation Accuracy: 72.948
# Epoch: 7
# Training Data: Epoch Loss: 0.442, Epoch Accuracy: 81.152, Validation Loss: 0.497,Validation Accuracy: 72.948
# Epoch: 8
# Training Data: Epoch Loss: 0.430, Epoch Accuracy: 81.152, Validation Loss: 0.486,Validation Accuracy: 72.948
# Epoch: 9
# Training Data: Epoch Loss: 0.414, Epoch Accuracy: 81.152, Validation Loss: 0.480,Validation Accuracy: 72.948
# Epoch: 10
# Training Data: Epoch Loss: 0.418, Epoch Accuracy: 81.152, Validation Loss: 0.500,Validation Accuracy: 72.948
# Epoch: 11
# Training Data: Epoch Loss: 0.405, Epoch Accuracy: 81.152, Validation Loss: 0.484,Validation Accuracy: 72.948
# Epoch: 12
# Training Data: Epoch Loss: 0.389, Epoch Accuracy: 81.152, Validation Loss: 0.453,Validation Accuracy: 72.948
# Epoch: 13
# Training Data: Epoch Loss: 0.405, Epoch Accuracy: 81.152, Validation Loss: 0.467,Validation Accuracy: 72.948
# Epoch: 14
# Training Data: Epoch Loss: 0.395, Epoch Accuracy: 81.152, Validation Loss: 0.453,Validation Accuracy: 72.948
# Epoch: 15
# Training Data: Epoch Loss: 0.390, Epoch Accuracy: 81.152, Validation Loss: 0.451,Validation Accuracy: 72.948
# Epoch: 16
# Training Data: Epoch Loss: 0.405, Epoch Accuracy: 81.152, Validation Loss: 0.448,Validation Accuracy: 72.948
# Epoch: 17
# Training Data: Epoch Loss: 0.388, Epoch Accuracy: 81.152, Validation Loss: 0.451,Validation Accuracy: 72.948
# Epoch: 18
# Training Data: Epoch Loss: 0.378, Epoch Accuracy: 81.152, Validation Loss: 0.439,Validation Accuracy: 72.948
# Epoch: 19
# Training Data: Epoch Loss: 0.380, Epoch Accuracy: 81.152, Validation Loss: 0.438,Validation Accuracy: 72.948
# Epoch: 20
# Training Data: Epoch Loss: 0.378, Epoch Accuracy: 81.152, Validation Loss: 0.439,Validation Accuracy: 72.948
# Epoch: 21
# Training Data: Epoch Loss: 0.378, Epoch Accuracy: 81.152, Validation Loss: 0.437,Validation Accuracy: 72.948
# Epoch: 22
# Training Data: Epoch Loss: 0.372, Epoch Accuracy: 81.152, Validation Loss: 0.436,Validation Accuracy: 72.948
# Epoch: 23
# Training Data: Epoch Loss: 0.376, Epoch Accuracy: 81.152, Validation Loss: 0.436,Validation Accuracy: 72.948
# Epoch: 24
# Training Data: Epoch Loss: 0.391, Epoch Accuracy: 81.152, Validation Loss: 0.440,Validation Accuracy: 72.948
# Epoch: 25
# Training Data: Epoch Loss: 0.371, Epoch Accuracy: 81.152, Validation Loss: 0.440,Validation Accuracy: 72.948
# Epoch: 26
# Training Data: Epoch Loss: 0.385, Epoch Accuracy: 81.152, Validation Loss: 0.448,Validation Accuracy: 72.948
# Epoch: 27
# Training Data: Epoch Loss: 0.380, Epoch Accuracy: 81.152, Validation Loss: 0.486,Validation Accuracy: 72.948
# Epoch: 28
# Training Data: Epoch Loss: 0.373, Epoch Accuracy: 81.152, Validation Loss: 0.490,Validation Accuracy: 72.948
# Epoch: 29
# Training Data: Epoch Loss: 0.396, Epoch Accuracy: 81.152, Validation Loss: 0.447,Validation Accuracy: 72.948
# Epoch: 30
# Training Data: Epoch Loss: 0.386, Epoch Accuracy: 80.664, Validation Loss: 0.458,Validation Accuracy: 72.948
# Epoch: 31
# Training Data: Epoch Loss: 0.383, Epoch Accuracy: 81.152, Validation Loss: 0.454,Validation Accuracy: 72.948
# Epoch: 32
# Training Data: Epoch Loss: 0.378, Epoch Accuracy: 79.785, Validation Loss: 0.504,Validation Accuracy: 72.948
# Epoch: 33
# Training Data: Epoch Loss: 0.383, Epoch Accuracy: 79.004, Validation Loss: 0.418,Validation Accuracy: 72.948
# Epoch: 34
# Training Data: Epoch Loss: 0.320, Epoch Accuracy: 82.422, Validation Loss: 0.513,Validation Accuracy: 80.851
# Epoch: 35
# Training Data: Epoch Loss: 0.260, Epoch Accuracy: 87.598, Validation Loss: 1.254,Validation Accuracy: 80.851
# Epoch: 36
# Training Data: Epoch Loss: 0.303, Epoch Accuracy: 86.035, Validation Loss: 1.443,Validation Accuracy: 72.948
# Epoch: 37
# Training Data: Epoch Loss: 0.265, Epoch Accuracy: 88.770, Validation Loss: 1.425,Validation Accuracy: 80.547
# Epoch: 38
# Training Data: Epoch Loss: 0.241, Epoch Accuracy: 89.551, Validation Loss: 0.331,Validation Accuracy: 87.386
# Epoch: 39
# Training Data: Epoch Loss: 0.282, Epoch Accuracy: 86.230, Validation Loss: 0.522,Validation Accuracy: 83.739
# Epoch: 40
# Training Data: Epoch Loss: 0.247, Epoch Accuracy: 87.598, Validation Loss: 0.438,Validation Accuracy: 88.450
# Epoch: 41
# Training Data: Epoch Loss: 0.205, Epoch Accuracy: 92.480, Validation Loss: 0.750,Validation Accuracy: 86.474
# Epoch: 42
# Training Data: Epoch Loss: 0.225, Epoch Accuracy: 89.746, Validation Loss: 0.309,Validation Accuracy: 87.842
# Epoch: 43
# Training Data: Epoch Loss: 0.194, Epoch Accuracy: 91.602, Validation Loss: 0.391,Validation Accuracy: 88.906
# Epoch: 44
# Training Data: Epoch Loss: 0.137, Epoch Accuracy: 94.434, Validation Loss: 0.404,Validation Accuracy: 89.210
# Epoch: 45
# Training Data: Epoch Loss: 0.211, Epoch Accuracy: 90.918, Validation Loss: 0.524,Validation Accuracy: 86.474
# Epoch: 46
# Training Data: Epoch Loss: 0.180, Epoch Accuracy: 93.848, Validation Loss: 0.539,Validation Accuracy: 88.602
# Epoch: 47
# Training Data: Epoch Loss: 0.147, Epoch Accuracy: 94.922, Validation Loss: 0.395,Validation Accuracy: 85.410
# Epoch: 48
# Training Data: Epoch Loss: 0.123, Epoch Accuracy: 95.312, Validation Loss: 0.500,Validation Accuracy: 87.994
# Epoch: 49
# Training Data: Epoch Loss: 0.117, Epoch Accuracy: 95.020, Validation Loss: 0.447,Validation Accuracy: 89.666
# Epoch: 50
# Training Data: Epoch Loss: 0.120, Epoch Accuracy: 96.387, Validation Loss: 0.439,Validation Accuracy: 89.514
# ######## epoch Finished in 503.08137917518616 seconds ###########
# Learning Rate: 0.100
# Batch Size: 64
# Epoch size: 50
# Epoch: 1
# Training Data: Epoch Loss: 1.025, Epoch Accuracy: 77.637, Validation Loss: 943.712,Validation Accuracy: 72.948
# Epoch: 2
# Training Data: Epoch Loss: 0.320, Epoch Accuracy: 81.348, Validation Loss: 3.100,Validation Accuracy: 75.684
# Epoch: 3
# Training Data: Epoch Loss: 0.224, Epoch Accuracy: 89.648, Validation Loss: 0.374,Validation Accuracy: 84.498
# Epoch: 4
# Training Data: Epoch Loss: 0.182, Epoch Accuracy: 93.945, Validation Loss: 0.343,Validation Accuracy: 87.994
# Epoch: 5
# Training Data: Epoch Loss: 0.162, Epoch Accuracy: 93.555, Validation Loss: 0.324,Validation Accuracy: 88.146
# Epoch: 6
# Training Data: Epoch Loss: 0.153, Epoch Accuracy: 95.312, Validation Loss: 0.430,Validation Accuracy: 86.778
# Epoch: 7
# Training Data: Epoch Loss: 0.133, Epoch Accuracy: 94.727, Validation Loss: 0.304,Validation Accuracy: 88.602
# Epoch: 8
# Training Data: Epoch Loss: 0.107, Epoch Accuracy: 96.387, Validation Loss: 0.236,Validation Accuracy: 93.921
# Epoch: 9
# Training Data: Epoch Loss: 0.090, Epoch Accuracy: 97.266, Validation Loss: 0.427,Validation Accuracy: 92.857
# Epoch: 10
# Training Data: Epoch Loss: 0.072, Epoch Accuracy: 97.266, Validation Loss: 0.379,Validation Accuracy: 93.769
# Epoch: 11
# Training Data: Epoch Loss: 0.094, Epoch Accuracy: 96.875, Validation Loss: 0.655,Validation Accuracy: 92.553
# Epoch: 12
# Training Data: Epoch Loss: 0.081, Epoch Accuracy: 96.875, Validation Loss: 0.265,Validation Accuracy: 94.529
# Epoch: 13
# Training Data: Epoch Loss: 0.054, Epoch Accuracy: 98.047, Validation Loss: 0.375,Validation Accuracy: 92.401
# Epoch: 14
# Training Data: Epoch Loss: 0.045, Epoch Accuracy: 98.730, Validation Loss: 0.265,Validation Accuracy: 95.441
# Epoch: 15
# Training Data: Epoch Loss: 0.047, Epoch Accuracy: 98.633, Validation Loss: 0.419,Validation Accuracy: 96.201
# Epoch: 16
# Training Data: Epoch Loss: 0.053, Epoch Accuracy: 98.242, Validation Loss: 0.260,Validation Accuracy: 95.593
# Epoch: 17
# Training Data: Epoch Loss: 0.036, Epoch Accuracy: 99.316, Validation Loss: 0.401,Validation Accuracy: 95.745
# Epoch: 18
# Training Data: Epoch Loss: 0.030, Epoch Accuracy: 99.219, Validation Loss: 0.387,Validation Accuracy: 95.441
# Epoch: 19
# Training Data: Epoch Loss: 0.031, Epoch Accuracy: 99.121, Validation Loss: 0.417,Validation Accuracy: 95.897
# Epoch: 20
# Training Data: Epoch Loss: 0.030, Epoch Accuracy: 99.414, Validation Loss: 0.436,Validation Accuracy: 95.289
# Epoch: 21
# Training Data: Epoch Loss: 0.025, Epoch Accuracy: 99.609, Validation Loss: 0.439,Validation Accuracy: 95.745
# Epoch: 22
# Training Data: Epoch Loss: 0.028, Epoch Accuracy: 99.414, Validation Loss: 0.428,Validation Accuracy: 96.049
# Epoch: 23
# Training Data: Epoch Loss: 0.027, Epoch Accuracy: 99.121, Validation Loss: 0.421,Validation Accuracy: 96.353
# Epoch: 24
# Training Data: Epoch Loss: 0.028, Epoch Accuracy: 99.512, Validation Loss: 0.445,Validation Accuracy: 96.049
# Epoch: 25
# Training Data: Epoch Loss: 0.030, Epoch Accuracy: 99.023, Validation Loss: 0.442,Validation Accuracy: 95.745
# Epoch: 26
# Training Data: Epoch Loss: 0.026, Epoch Accuracy: 99.023, Validation Loss: 0.484,Validation Accuracy: 95.897
# Epoch: 27
# Training Data: Epoch Loss: 0.028, Epoch Accuracy: 98.828, Validation Loss: 0.396,Validation Accuracy: 96.049
# Epoch: 28
# Training Data: Epoch Loss: 0.028, Epoch Accuracy: 99.219, Validation Loss: 0.377,Validation Accuracy: 95.289
# Epoch: 29
# Training Data: Epoch Loss: 0.066, Epoch Accuracy: 97.461, Validation Loss: 0.541,Validation Accuracy: 93.009
# Epoch: 30
# Training Data: Epoch Loss: 0.060, Epoch Accuracy: 98.242, Validation Loss: 0.460,Validation Accuracy: 92.705
# Epoch: 31
# Training Data: Epoch Loss: 0.059, Epoch Accuracy: 98.145, Validation Loss: 0.417,Validation Accuracy: 94.985
# Epoch: 32
# Training Data: Epoch Loss: 0.060, Epoch Accuracy: 97.754, Validation Loss: 0.897,Validation Accuracy: 90.122
# Epoch: 33
# Training Data: Epoch Loss: 0.071, Epoch Accuracy: 97.949, Validation Loss: 0.594,Validation Accuracy: 93.009
# Epoch: 34
# Training Data: Epoch Loss: 0.061, Epoch Accuracy: 97.754, Validation Loss: 0.618,Validation Accuracy: 92.097
# Epoch: 35
# Training Data: Epoch Loss: 0.043, Epoch Accuracy: 98.730, Validation Loss: 0.813,Validation Accuracy: 94.377
# Epoch: 36
# Training Data: Epoch Loss: 0.041, Epoch Accuracy: 98.730, Validation Loss: 0.961,Validation Accuracy: 88.906
# Epoch: 37
# Training Data: Epoch Loss: 0.050, Epoch Accuracy: 98.535, Validation Loss: 0.561,Validation Accuracy: 94.833
# Epoch: 38
# Training Data: Epoch Loss: 0.044, Epoch Accuracy: 98.438, Validation Loss: 1.122,Validation Accuracy: 92.705
# Epoch: 39
# Training Data: Epoch Loss: 0.044, Epoch Accuracy: 98.535, Validation Loss: 0.688,Validation Accuracy: 94.681
# Epoch: 40
# Training Data: Epoch Loss: 0.084, Epoch Accuracy: 96.582, Validation Loss: 0.698,Validation Accuracy: 82.219
# Epoch: 41
# Training Data: Epoch Loss: 0.078, Epoch Accuracy: 96.387, Validation Loss: 0.483,Validation Accuracy: 91.945
# Epoch: 42
# Training Data: Epoch Loss: 0.062, Epoch Accuracy: 97.949, Validation Loss: 0.514,Validation Accuracy: 92.705
# Epoch: 43
# Training Data: Epoch Loss: 0.040, Epoch Accuracy: 98.730, Validation Loss: 0.534,Validation Accuracy: 96.809
# Epoch: 44
# Training Data: Epoch Loss: 0.033, Epoch Accuracy: 98.340, Validation Loss: 0.631,Validation Accuracy: 97.112
# Epoch: 45
# Training Data: Epoch Loss: 0.035, Epoch Accuracy: 98.730, Validation Loss: 0.493,Validation Accuracy: 96.809
# Epoch: 46
# Training Data: Epoch Loss: 0.035, Epoch Accuracy: 98.633, Validation Loss: 1.342,Validation Accuracy: 94.985
# Epoch: 47
# Training Data: Epoch Loss: 0.024, Epoch Accuracy: 98.828, Validation Loss: 1.788,Validation Accuracy: 93.769
# Epoch: 48
# Training Data: Epoch Loss: 0.024, Epoch Accuracy: 99.121, Validation Loss: 0.941,Validation Accuracy: 95.897
# Epoch: 49
# Training Data: Epoch Loss: 0.021, Epoch Accuracy: 99.316, Validation Loss: 0.894,Validation Accuracy: 95.745
# Epoch: 50
# Training Data: Epoch Loss: 0.017, Epoch Accuracy: 99.316, Validation Loss: 0.700,Validation Accuracy: 96.201
# ######## epoch Finished in 502.00277280807495 seconds ###########
# Learning Rate: 0.010
# Batch Size: 64
# Epoch size: 50
# Epoch: 1
# Training Data: Epoch Loss: 0.420, Epoch Accuracy: 83.398, Validation Loss: 1.168,Validation Accuracy: 72.948
# Epoch: 2
# Training Data: Epoch Loss: 0.127, Epoch Accuracy: 94.336, Validation Loss: 0.679,Validation Accuracy: 86.778
# Epoch: 3
# Training Data: Epoch Loss: 0.086, Epoch Accuracy: 97.266, Validation Loss: 0.325,Validation Accuracy: 92.857
# Epoch: 4
# Training Data: Epoch Loss: 0.094, Epoch Accuracy: 95.703, Validation Loss: 0.364,Validation Accuracy: 92.249
# Epoch: 5
# Training Data: Epoch Loss: 0.060, Epoch Accuracy: 97.461, Validation Loss: 0.230,Validation Accuracy: 94.073
# Epoch: 6
# Training Data: Epoch Loss: 0.048, Epoch Accuracy: 98.340, Validation Loss: 0.259,Validation Accuracy: 92.249
# Epoch: 7
# Training Data: Epoch Loss: 0.039, Epoch Accuracy: 98.340, Validation Loss: 0.286,Validation Accuracy: 93.465
# Epoch: 8
# Training Data: Epoch Loss: 0.040, Epoch Accuracy: 98.828, Validation Loss: 0.318,Validation Accuracy: 93.009
# Epoch: 9
# Training Data: Epoch Loss: 0.026, Epoch Accuracy: 99.219, Validation Loss: 0.458,Validation Accuracy: 89.970
# Epoch: 10
# Training Data: Epoch Loss: 0.024, Epoch Accuracy: 99.316, Validation Loss: 0.159,Validation Accuracy: 96.353
# Epoch: 11
# Training Data: Epoch Loss: 0.016, Epoch Accuracy: 99.512, Validation Loss: 0.173,Validation Accuracy: 95.137
# Epoch: 12
# Training Data: Epoch Loss: 0.020, Epoch Accuracy: 99.316, Validation Loss: 0.152,Validation Accuracy: 95.897
# Epoch: 13
# Training Data: Epoch Loss: 0.021, Epoch Accuracy: 99.121, Validation Loss: 0.209,Validation Accuracy: 94.377
# Epoch: 14
# Training Data: Epoch Loss: 0.014, Epoch Accuracy: 99.707, Validation Loss: 0.203,Validation Accuracy: 95.137
# Epoch: 15
# Training Data: Epoch Loss: 0.009, Epoch Accuracy: 99.707, Validation Loss: 0.111,Validation Accuracy: 96.657
# Epoch: 16
# Training Data: Epoch Loss: 0.011, Epoch Accuracy: 99.609, Validation Loss: 0.143,Validation Accuracy: 96.809
# Epoch: 17
# Training Data: Epoch Loss: 0.005, Epoch Accuracy: 100.000, Validation Loss: 0.167,Validation Accuracy: 96.049
# Epoch: 18
# Training Data: Epoch Loss: 0.006, Epoch Accuracy: 99.805, Validation Loss: 0.148,Validation Accuracy: 96.353
# Epoch: 19
# Training Data: Epoch Loss: 0.007, Epoch Accuracy: 99.805, Validation Loss: 0.153,Validation Accuracy: 96.049
# Epoch: 20
# Training Data: Epoch Loss: 0.006, Epoch Accuracy: 99.902, Validation Loss: 0.152,Validation Accuracy: 96.201
# Epoch: 21
# Training Data: Epoch Loss: 0.007, Epoch Accuracy: 99.805, Validation Loss: 0.162,Validation Accuracy: 96.049
# Epoch: 22
# Training Data: Epoch Loss: 0.004, Epoch Accuracy: 100.000, Validation Loss: 0.150,Validation Accuracy: 96.049
# Epoch: 23
# Training Data: Epoch Loss: 0.010, Epoch Accuracy: 99.609, Validation Loss: 0.159,Validation Accuracy: 96.049
# Epoch: 24
# Training Data: Epoch Loss: 0.006, Epoch Accuracy: 99.902, Validation Loss: 0.149,Validation Accuracy: 96.201
# Epoch: 25
# Training Data: Epoch Loss: 0.009, Epoch Accuracy: 99.609, Validation Loss: 0.181,Validation Accuracy: 96.201
# Epoch: 26
# Training Data: Epoch Loss: 0.008, Epoch Accuracy: 99.707, Validation Loss: 0.147,Validation Accuracy: 96.657
# Epoch: 27
# Training Data: Epoch Loss: 0.007, Epoch Accuracy: 99.707, Validation Loss: 0.157,Validation Accuracy: 96.657
# Epoch: 28
# Training Data: Epoch Loss: 0.006, Epoch Accuracy: 99.902, Validation Loss: 0.158,Validation Accuracy: 96.657
# Epoch: 29
# Training Data: Epoch Loss: 0.009, Epoch Accuracy: 99.512, Validation Loss: 0.280,Validation Accuracy: 94.529
# Epoch: 30
# Training Data: Epoch Loss: 0.007, Epoch Accuracy: 99.805, Validation Loss: 0.221,Validation Accuracy: 94.377
# Epoch: 31
# Training Data: Epoch Loss: 0.008, Epoch Accuracy: 99.707, Validation Loss: 0.116,Validation Accuracy: 96.960
# Epoch: 32
# Training Data: Epoch Loss: 0.006, Epoch Accuracy: 99.707, Validation Loss: 0.176,Validation Accuracy: 96.201
# Epoch: 33
# Training Data: Epoch Loss: 0.014, Epoch Accuracy: 99.512, Validation Loss: 0.374,Validation Accuracy: 92.857
# Epoch: 34
# Training Data: Epoch Loss: 0.010, Epoch Accuracy: 99.512, Validation Loss: 0.223,Validation Accuracy: 94.681
# Epoch: 35
# Training Data: Epoch Loss: 0.020, Epoch Accuracy: 99.316, Validation Loss: 0.221,Validation Accuracy: 95.593
# Epoch: 36
# Training Data: Epoch Loss: 0.008, Epoch Accuracy: 99.805, Validation Loss: 0.190,Validation Accuracy: 95.897
# Epoch: 37
# Training Data: Epoch Loss: 0.020, Epoch Accuracy: 99.414, Validation Loss: 0.160,Validation Accuracy: 96.353
# Epoch: 38
# Training Data: Epoch Loss: 0.014, Epoch Accuracy: 99.707, Validation Loss: 0.144,Validation Accuracy: 95.593
# Epoch: 39
# Training Data: Epoch Loss: 0.067, Epoch Accuracy: 97.852, Validation Loss: 0.754,Validation Accuracy: 90.426
# Epoch: 40
# Training Data: Epoch Loss: 0.081, Epoch Accuracy: 97.266, Validation Loss: 0.326,Validation Accuracy: 91.641
# Epoch: 41
# Training Data: Epoch Loss: 0.039, Epoch Accuracy: 98.535, Validation Loss: 0.160,Validation Accuracy: 95.441
# Epoch: 42
# Training Data: Epoch Loss: 0.022, Epoch Accuracy: 99.219, Validation Loss: 0.134,Validation Accuracy: 95.593
# Epoch: 43
# Training Data: Epoch Loss: 0.024, Epoch Accuracy: 99.121, Validation Loss: 0.354,Validation Accuracy: 92.401
# Epoch: 44
# Training Data: Epoch Loss: 0.020, Epoch Accuracy: 99.512, Validation Loss: 0.267,Validation Accuracy: 92.857
# Epoch: 45
# Training Data: Epoch Loss: 0.010, Epoch Accuracy: 99.609, Validation Loss: 0.169,Validation Accuracy: 95.441
# Epoch: 46
# Training Data: Epoch Loss: 0.009, Epoch Accuracy: 99.805, Validation Loss: 0.180,Validation Accuracy: 96.049
# Epoch: 47
# Training Data: Epoch Loss: 0.016, Epoch Accuracy: 99.316, Validation Loss: 0.127,Validation Accuracy: 96.657
# Epoch: 48
# Training Data: Epoch Loss: 0.012, Epoch Accuracy: 99.609, Validation Loss: 0.096,Validation Accuracy: 97.416
# Epoch: 49
# Training Data: Epoch Loss: 0.007, Epoch Accuracy: 99.707, Validation Loss: 0.259,Validation Accuracy: 94.529
# Epoch: 50
# Training Data: Epoch Loss: 0.004, Epoch Accuracy: 100.000, Validation Loss: 0.190,Validation Accuracy: 95.897
# ######## epoch Finished in 504.21023416519165 seconds ###########
# Learning Rate: 0.001
# Batch Size: 64
# Epoch size: 50
# Epoch: 1
# Training Data: Epoch Loss: 0.483, Epoch Accuracy: 81.152, Validation Loss: 0.546,Validation Accuracy: 72.948
# Epoch: 2
# Training Data: Epoch Loss: 0.403, Epoch Accuracy: 81.152, Validation Loss: 0.490,Validation Accuracy: 72.948
# Epoch: 3
# Training Data: Epoch Loss: 0.274, Epoch Accuracy: 88.867, Validation Loss: 0.314,Validation Accuracy: 83.435
# Epoch: 4
# Training Data: Epoch Loss: 0.163, Epoch Accuracy: 95.605, Validation Loss: 0.219,Validation Accuracy: 92.097
# Epoch: 5
# Training Data: Epoch Loss: 0.108, Epoch Accuracy: 96.680, Validation Loss: 0.213,Validation Accuracy: 91.793
# Epoch: 6
# Training Data: Epoch Loss: 0.077, Epoch Accuracy: 98.242, Validation Loss: 0.185,Validation Accuracy: 93.465
# Epoch: 7
# Training Data: Epoch Loss: 0.064, Epoch Accuracy: 97.754, Validation Loss: 0.156,Validation Accuracy: 93.921
# Epoch: 8
# Training Data: Epoch Loss: 0.053, Epoch Accuracy: 99.023, Validation Loss: 0.142,Validation Accuracy: 93.769
# Epoch: 9
# Training Data: Epoch Loss: 0.048, Epoch Accuracy: 98.535, Validation Loss: 0.120,Validation Accuracy: 95.137
# Epoch: 10
# Training Data: Epoch Loss: 0.050, Epoch Accuracy: 98.340, Validation Loss: 0.199,Validation Accuracy: 93.161
# Epoch: 11
# Training Data: Epoch Loss: 0.049, Epoch Accuracy: 98.145, Validation Loss: 0.152,Validation Accuracy: 94.529
# Epoch: 12
# Training Data: Epoch Loss: 0.041, Epoch Accuracy: 98.730, Validation Loss: 0.148,Validation Accuracy: 93.921
# Epoch: 13
# Training Data: Epoch Loss: 0.031, Epoch Accuracy: 99.219, Validation Loss: 0.165,Validation Accuracy: 93.921
# Epoch: 14
# Training Data: Epoch Loss: 0.040, Epoch Accuracy: 98.633, Validation Loss: 0.125,Validation Accuracy: 94.529
# Epoch: 15
# Training Data: Epoch Loss: 0.032, Epoch Accuracy: 99.023, Validation Loss: 0.131,Validation Accuracy: 94.681
# Epoch: 16
# Training Data: Epoch Loss: 0.033, Epoch Accuracy: 98.828, Validation Loss: 0.131,Validation Accuracy: 94.833
# Epoch: 17
# Training Data: Epoch Loss: 0.040, Epoch Accuracy: 98.535, Validation Loss: 0.153,Validation Accuracy: 94.073
# Epoch: 18
# Training Data: Epoch Loss: 0.028, Epoch Accuracy: 99.316, Validation Loss: 0.150,Validation Accuracy: 94.529
# Epoch: 19
# Training Data: Epoch Loss: 0.034, Epoch Accuracy: 98.926, Validation Loss: 0.126,Validation Accuracy: 95.137
# Epoch: 20
# Training Data: Epoch Loss: 0.031, Epoch Accuracy: 99.512, Validation Loss: 0.135,Validation Accuracy: 94.377
# Epoch: 21
# Training Data: Epoch Loss: 0.028, Epoch Accuracy: 99.121, Validation Loss: 0.143,Validation Accuracy: 94.681
# Epoch: 22
# Training Data: Epoch Loss: 0.030, Epoch Accuracy: 99.316, Validation Loss: 0.123,Validation Accuracy: 94.681
# Epoch: 23
# Training Data: Epoch Loss: 0.034, Epoch Accuracy: 99.023, Validation Loss: 0.132,Validation Accuracy: 95.137
# Epoch: 24
# Training Data: Epoch Loss: 0.030, Epoch Accuracy: 99.023, Validation Loss: 0.129,Validation Accuracy: 95.137
# Epoch: 25
# Training Data: Epoch Loss: 0.032, Epoch Accuracy: 99.121, Validation Loss: 0.119,Validation Accuracy: 95.137
# Epoch: 26
# Training Data: Epoch Loss: 0.024, Epoch Accuracy: 99.512, Validation Loss: 0.172,Validation Accuracy: 93.921
# Epoch: 27
# Training Data: Epoch Loss: 0.026, Epoch Accuracy: 99.414, Validation Loss: 0.123,Validation Accuracy: 95.137
# Epoch: 28
# Training Data: Epoch Loss: 0.029, Epoch Accuracy: 99.219, Validation Loss: 0.145,Validation Accuracy: 94.073
# Epoch: 29
# Training Data: Epoch Loss: 0.022, Epoch Accuracy: 99.316, Validation Loss: 0.131,Validation Accuracy: 95.289
# Epoch: 30
# Training Data: Epoch Loss: 0.028, Epoch Accuracy: 99.219, Validation Loss: 0.126,Validation Accuracy: 94.833
# Epoch: 31
# Training Data: Epoch Loss: 0.024, Epoch Accuracy: 99.316, Validation Loss: 0.132,Validation Accuracy: 94.985
# Epoch: 32
# Training Data: Epoch Loss: 0.031, Epoch Accuracy: 98.926, Validation Loss: 0.167,Validation Accuracy: 93.769
# Epoch: 33
# Training Data: Epoch Loss: 0.025, Epoch Accuracy: 99.219, Validation Loss: 0.102,Validation Accuracy: 96.201
# Epoch: 34
# Training Data: Epoch Loss: 0.029, Epoch Accuracy: 99.121, Validation Loss: 0.245,Validation Accuracy: 92.553
# Epoch: 35
# Training Data: Epoch Loss: 0.023, Epoch Accuracy: 99.414, Validation Loss: 0.123,Validation Accuracy: 95.897
# Epoch: 36
# Training Data: Epoch Loss: 0.020, Epoch Accuracy: 99.512, Validation Loss: 0.188,Validation Accuracy: 93.921
# Epoch: 37
# Training Data: Epoch Loss: 0.021, Epoch Accuracy: 99.609, Validation Loss: 0.095,Validation Accuracy: 96.657
# Epoch: 38
# Training Data: Epoch Loss: 0.020, Epoch Accuracy: 99.316, Validation Loss: 0.144,Validation Accuracy: 94.833
# Epoch: 39
# Training Data: Epoch Loss: 0.016, Epoch Accuracy: 99.707, Validation Loss: 0.138,Validation Accuracy: 96.049
# Epoch: 40
# Training Data: Epoch Loss: 0.024, Epoch Accuracy: 99.219, Validation Loss: 0.217,Validation Accuracy: 93.161
# Epoch: 41
# Training Data: Epoch Loss: 0.019, Epoch Accuracy: 99.414, Validation Loss: 0.163,Validation Accuracy: 94.681
# Epoch: 42
# Training Data: Epoch Loss: 0.015, Epoch Accuracy: 99.707, Validation Loss: 0.120,Validation Accuracy: 96.353
# Epoch: 43
# Training Data: Epoch Loss: 0.034, Epoch Accuracy: 98.730, Validation Loss: 0.116,Validation Accuracy: 95.897
# Epoch: 44
# Training Data: Epoch Loss: 0.018, Epoch Accuracy: 99.707, Validation Loss: 0.105,Validation Accuracy: 96.353
# Epoch: 45
# Training Data: Epoch Loss: 0.022, Epoch Accuracy: 98.828, Validation Loss: 0.174,Validation Accuracy: 94.529
# Epoch: 46
# Training Data: Epoch Loss: 0.028, Epoch Accuracy: 98.828, Validation Loss: 0.105,Validation Accuracy: 96.201
# Epoch: 47
# Training Data: Epoch Loss: 0.019, Epoch Accuracy: 99.512, Validation Loss: 0.177,Validation Accuracy: 94.833
# Epoch: 48
# Training Data: Epoch Loss: 0.026, Epoch Accuracy: 98.730, Validation Loss: 0.128,Validation Accuracy: 96.809
# Epoch: 49
# Training Data: Epoch Loss: 0.015, Epoch Accuracy: 99.609, Validation Loss: 0.124,Validation Accuracy: 95.745
# Epoch: 50
# Training Data: Epoch Loss: 0.013, Epoch Accuracy: 99.707, Validation Loss: 0.144,Validation Accuracy: 95.289
# ######## epoch Finished in 508.79707503318787 seconds ###########
# Learning Rate: 0.000
# Batch Size: 64
# Epoch size: 50
# Epoch: 1
# Training Data: Epoch Loss: 0.510, Epoch Accuracy: 81.152, Validation Loss: 0.564,Validation Accuracy: 72.948
# Epoch: 2
# Training Data: Epoch Loss: 0.476, Epoch Accuracy: 81.152, Validation Loss: 0.553,Validation Accuracy: 72.948
# Epoch: 3
# Training Data: Epoch Loss: 0.464, Epoch Accuracy: 81.152, Validation Loss: 0.550,Validation Accuracy: 72.948
# Epoch: 4
# Training Data: Epoch Loss: 0.455, Epoch Accuracy: 81.152, Validation Loss: 0.534,Validation Accuracy: 72.948
# Epoch: 5
# Training Data: Epoch Loss: 0.445, Epoch Accuracy: 81.152, Validation Loss: 0.523,Validation Accuracy: 72.948
# Epoch: 6
# Training Data: Epoch Loss: 0.433, Epoch Accuracy: 81.152, Validation Loss: 0.513,Validation Accuracy: 72.948
# Epoch: 7
# Training Data: Epoch Loss: 0.426, Epoch Accuracy: 81.152, Validation Loss: 0.501,Validation Accuracy: 72.948
# Epoch: 8
# Training Data: Epoch Loss: 0.411, Epoch Accuracy: 81.152, Validation Loss: 0.491,Validation Accuracy: 72.948
# Epoch: 9
# Training Data: Epoch Loss: 0.398, Epoch Accuracy: 81.152, Validation Loss: 0.473,Validation Accuracy: 72.948
# Epoch: 10
# Training Data: Epoch Loss: 0.388, Epoch Accuracy: 81.152, Validation Loss: 0.455,Validation Accuracy: 72.948
# Epoch: 11
# Training Data: Epoch Loss: 0.371, Epoch Accuracy: 81.250, Validation Loss: 0.449,Validation Accuracy: 72.948
# Epoch: 12
# Training Data: Epoch Loss: 0.356, Epoch Accuracy: 81.250, Validation Loss: 0.430,Validation Accuracy: 73.252
# Epoch: 13
# Training Data: Epoch Loss: 0.338, Epoch Accuracy: 81.836, Validation Loss: 0.406,Validation Accuracy: 74.316
# Epoch: 14
# Training Data: Epoch Loss: 0.323, Epoch Accuracy: 83.008, Validation Loss: 0.389,Validation Accuracy: 75.532
# Epoch: 15
# Training Data: Epoch Loss: 0.305, Epoch Accuracy: 84.277, Validation Loss: 0.375,Validation Accuracy: 77.052
# Epoch: 16
# Training Data: Epoch Loss: 0.287, Epoch Accuracy: 85.254, Validation Loss: 0.355,Validation Accuracy: 80.243
# Epoch: 17
# Training Data: Epoch Loss: 0.266, Epoch Accuracy: 87.988, Validation Loss: 0.338,Validation Accuracy: 83.131
# Epoch: 18
# Training Data: Epoch Loss: 0.250, Epoch Accuracy: 90.332, Validation Loss: 0.319,Validation Accuracy: 86.170
# Epoch: 19
# Training Data: Epoch Loss: 0.237, Epoch Accuracy: 92.676, Validation Loss: 0.306,Validation Accuracy: 88.450
# Epoch: 20
# Training Data: Epoch Loss: 0.221, Epoch Accuracy: 94.531, Validation Loss: 0.291,Validation Accuracy: 89.514
# Epoch: 21
# Training Data: Epoch Loss: 0.206, Epoch Accuracy: 94.922, Validation Loss: 0.281,Validation Accuracy: 89.818
# Epoch: 22
# Training Data: Epoch Loss: 0.192, Epoch Accuracy: 95.898, Validation Loss: 0.266,Validation Accuracy: 91.033
# Epoch: 23
# Training Data: Epoch Loss: 0.177, Epoch Accuracy: 96.387, Validation Loss: 0.254,Validation Accuracy: 91.793
# Epoch: 24
# Training Data: Epoch Loss: 0.165, Epoch Accuracy: 96.777, Validation Loss: 0.251,Validation Accuracy: 91.185
# Epoch: 25
# Training Data: Epoch Loss: 0.156, Epoch Accuracy: 96.484, Validation Loss: 0.239,Validation Accuracy: 91.793
# Epoch: 26
# Training Data: Epoch Loss: 0.152, Epoch Accuracy: 96.582, Validation Loss: 0.235,Validation Accuracy: 91.641
# Epoch: 27
# Training Data: Epoch Loss: 0.144, Epoch Accuracy: 97.168, Validation Loss: 0.230,Validation Accuracy: 91.945
# Epoch: 28
# Training Data: Epoch Loss: 0.136, Epoch Accuracy: 96.777, Validation Loss: 0.219,Validation Accuracy: 92.097
# Epoch: 29
# Training Data: Epoch Loss: 0.133, Epoch Accuracy: 97.070, Validation Loss: 0.219,Validation Accuracy: 91.945
# Epoch: 30
# Training Data: Epoch Loss: 0.123, Epoch Accuracy: 97.070, Validation Loss: 0.217,Validation Accuracy: 91.945
# Epoch: 31
# Training Data: Epoch Loss: 0.119, Epoch Accuracy: 97.266, Validation Loss: 0.211,Validation Accuracy: 92.401
# Epoch: 32
# Training Data: Epoch Loss: 0.110, Epoch Accuracy: 97.461, Validation Loss: 0.207,Validation Accuracy: 92.097
# Epoch: 33
# Training Data: Epoch Loss: 0.111, Epoch Accuracy: 97.559, Validation Loss: 0.206,Validation Accuracy: 92.097
# Epoch: 34
# Training Data: Epoch Loss: 0.103, Epoch Accuracy: 97.559, Validation Loss: 0.203,Validation Accuracy: 92.097
# Epoch: 35
# Training Data: Epoch Loss: 0.101, Epoch Accuracy: 97.461, Validation Loss: 0.201,Validation Accuracy: 91.793
# Epoch: 36
# Training Data: Epoch Loss: 0.100, Epoch Accuracy: 97.754, Validation Loss: 0.199,Validation Accuracy: 92.097
# Epoch: 37
# Training Data: Epoch Loss: 0.093, Epoch Accuracy: 97.754, Validation Loss: 0.191,Validation Accuracy: 92.705
# Epoch: 38
# Training Data: Epoch Loss: 0.093, Epoch Accuracy: 97.852, Validation Loss: 0.186,Validation Accuracy: 92.857
# Epoch: 39
# Training Data: Epoch Loss: 0.091, Epoch Accuracy: 97.266, Validation Loss: 0.192,Validation Accuracy: 92.249
# Epoch: 40
# Training Data: Epoch Loss: 0.092, Epoch Accuracy: 97.363, Validation Loss: 0.187,Validation Accuracy: 92.553
# Epoch: 41
# Training Data: Epoch Loss: 0.086, Epoch Accuracy: 97.852, Validation Loss: 0.193,Validation Accuracy: 92.401
# Epoch: 42
# Training Data: Epoch Loss: 0.082, Epoch Accuracy: 97.754, Validation Loss: 0.188,Validation Accuracy: 92.553
# Epoch: 43
# Training Data: Epoch Loss: 0.076, Epoch Accuracy: 98.438, Validation Loss: 0.179,Validation Accuracy: 92.857
# Epoch: 44
# Training Data: Epoch Loss: 0.081, Epoch Accuracy: 97.461, Validation Loss: 0.177,Validation Accuracy: 92.857
# Epoch: 45
# Training Data: Epoch Loss: 0.071, Epoch Accuracy: 98.340, Validation Loss: 0.176,Validation Accuracy: 92.857
# Epoch: 46
# Training Data: Epoch Loss: 0.075, Epoch Accuracy: 97.363, Validation Loss: 0.178,Validation Accuracy: 92.553
# Epoch: 47
# Training Data: Epoch Loss: 0.074, Epoch Accuracy: 98.047, Validation Loss: 0.173,Validation Accuracy: 92.857
# Epoch: 48
# Training Data: Epoch Loss: 0.065, Epoch Accuracy: 98.730, Validation Loss: 0.170,Validation Accuracy: 92.857
# Epoch: 49
# Training Data: Epoch Loss: 0.069, Epoch Accuracy: 97.852, Validation Loss: 0.164,Validation Accuracy: 93.313
# Epoch: 50
# Training Data: Epoch Loss: 0.062, Epoch Accuracy: 98.242, Validation Loss: 0.166,Validation Accuracy: 93.465
# ######## epoch Finished in 499.82299613952637 seconds ###########

# %%
len(lr_accuract_training)
len(lr_accuracy_val)
# Out:
# 5

# %%
plt.plot(range(5),lr_accuract_training, label="Training")
plt.plot(range(5),lr_accuracy_val, label="Validation")
plt.xlabel("Learning Rate")
plt.ylabel("Accuracies")
plt.title("Training vs Validation vs Test Accuracies with learning rate")
plt.legend()
plt.show()

# %%
plt.plot(range(5),lr_loss_train, label="Training")
plt.plot(range(5),lr_loss_val, label="Validation")
plt.xlabel("Folds")
plt.ylabel("Accuracies")
plt.title("Training vs Validation vs Test Loss with learning rate")
plt.legend()
plt.show()

# %%
print(best_param)
# Out:
# Learning Rate: 0.01 Batch Size: 64

# %%
model_path = 'best_checkpoint.model'

# %%
state_dict = torch.load(model_path)

# %%
model = models.resnet18(pretrained=False, num_classes=2)
model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %%
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
testing_loader = torch.utils.data.DataLoader(testing_dataset, batch_size=32, shuffle=False)

# %%
def evaluate_model(model,test_loader):
    model.eval()
    predicted_correct =0
    total = 0
    with torch.no_grad():
        for data in test_loader:
            images,labels = data
            images = images.to(device)
            labels = labels.to(device)
            total+=labels.size(0)
            outputs = model(images)
            _,predicted = torch.max(outputs,1)
            predicted_correct += (predicted == labels).sum().item()
    epoch_accuracy = 100.0* predicted_correct/total
    print("Testing Data: Epoch Accuracy: %.3f"%(epoch_accuracy))
    return epoch_accuracy

# %%
evaluate_model(model,testing_loader)
# Out:
# Testing Data: Epoch Accuracy: 90.000
# 90.0

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score,ConfusionMatrixDisplay

# %%
y_pred = []
y_true = []

for data in testing_loader:
        inputs, labels = data[0].to(device), data[1].to(device)
        output = resnet18_Model(inputs) 
        output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
        y_pred.extend(output) 
        labels = labels.data.cpu().numpy()
        y_true.extend(labels)

# %%
classes = (0,1)
confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix(y_true, y_pred),display_labels=classes)
fig,ax = plt.subplots()
fig.set_size_inches(13,13)
plt.title("Confusion Matrix ResNet 34 (2-Classes)")
disp.plot(ax=ax)
plt.show()

# %%
print("Precision Macro:{:.2f}".format(precision_score(y_true, y_pred, average='macro')))
print("Precision Micro:{:.2f}".format(precision_score(y_true,y_pred,average='micro')))
print("Recall Macro:{:.2f}".format(recall_score(y_true,y_pred,average='macro')))
print("Recall Micro:{:.2f}".format(recall_score(y_true,y_pred,average='micro')))
print("F1-Score Macro:{:.2f}".format(f1_score(y_true,y_pred,average='macro')))
print("F1-Score Micro:{:.2f}".format(f1_score(y_true,y_pred,average='micro')))
# Out:
# Precision Macro:0.77
# Precision Micro:0.84
# Recall Macro:0.71
# Recall Micro:0.84
# F1-Score Macro:0.73
# F1-Score Micro:0.84
